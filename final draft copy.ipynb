# %%
# @title Setup and Installation
print("Installing required packages...")
# %pip install -q tsplib95 numpy pandas matplotlib seaborn scipy optuna

# Import all libraries
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import time
import optuna
import logging
from typing import List, Tuple, Dict, Any
from dataclasses import dataclass
import urllib.request
import os
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Mute Optuna's default verbose logging to preserve clean console outputs
optuna.logging.set_verbosity(optuna.logging.WARNING)

print("Setup complete.")
# Out:
# Installing required packages...
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: pip3.14 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Setup complete.

# %%
# @title Download TSPLIB and QAPLIB Instances
print("Downloading problem instances...")

# Create directories
# !mkdir -p tsp_data qap_data

# Import required libraries for SSL handling
import ssl
import urllib.request
import gzip
import shutil
import os

# Create SSL context that doesn't verify certificates (for Colab)
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE

# TSP instances URLs (updated to working HTTPS links)
tsp_urls = {
    # Original instances
    'eil51': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/eil51.tsp.gz',
    'berlin52': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/berlin52.tsp.gz',
    'st70': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/st70.tsp.gz',
    'pr76': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/pr76.tsp.gz',
    
    # Harder TSP instances
    'eil101': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/eil101.tsp.gz',
    'ch130': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/ch130.tsp.gz',
    'tsp225': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/tsp225.tsp.gz',
    'a280': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/a280.tsp.gz',
    'lin318': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/lin318.tsp.gz',
    'pcb442': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/pcb442.tsp.gz',
    'att532': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/att532.tsp.gz',
    'rat575': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/rat575.tsp.gz',
    'rat783': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/rat783.tsp.gz',
    'pr1002': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/pr1002.tsp.gz',
    'u1060': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/u1060.tsp.gz',
    'vm1084': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/vm1084.tsp.gz',
    'pcb1173': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/pcb1173.tsp.gz',
    'd1291': 'https://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/d1291.tsp.gz',
} 

# QAP instances URLs (updated to working links)
qap_urls = {
    # Original instances
    'tai12a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai12a.dat',
    'tai15a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai15a.dat',
    'nug12': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/nug12.dat',
    'chr12a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/chr12a.dat',
    
    # Harder QAP instances
    'tai20a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai20a.dat',
    'tai25a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai25a.dat',
    'tai30a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai30a.dat',
    'tai35a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai35a.dat',
    'tai40a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai40a.dat',
    'tai50a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai50a.dat',
    'tai60a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai60a.dat',
    'tai80a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai80a.dat',
    'tai100a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tai100a.dat',
    'nug20': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/nug20.dat',
    'nug30': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/nug30.dat',
    'sko42': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/sko42.dat',
    'sko49': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/sko49.dat',
    'sko56': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/sko56.dat',
    'sko64': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/sko64.dat',
    'sko72': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/sko72.dat',
    'sko81': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/sko81.dat',
    'sko90': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/sko90.dat',
    'sko100a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/sko100a.dat',
    'wil50': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/wil50.dat',
    'wil100': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/wil100.dat',
    'tho30': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tho30.dat',
    'tho40': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tho40.dat',
    'tho150': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/tho150.dat',
    'chr20a': 'https://coral.ise.lehigh.edu/wp-content/uploads/2014/07/data.d/chr20a.dat',
}

def download_and_extract(url, output_file):
    """Download file with SSL handling, handle .gz if needed"""
    try:
        # Create request with SSL context
        req = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        
        if url.endswith('.gz'):
            temp_file = output_file + '.gz'
            
            # Download with SSL context
            with urllib.request.urlopen(req, context=ssl_context) as response:
                with open(temp_file, 'wb') as f:
                    f.write(response.read())
            
            # Extract .gz file
            with gzip.open(temp_file, 'rb') as f_in:
                with open(output_file, 'wb') as f_out:
                    shutil.copyfileobj(f_in, f_out)
            
            # Remove temporary .gz file
            os.remove(temp_file)
            print(f"    Extracted: {os.path.basename(output_file)}")
        else:
            # Download regular file
            with urllib.request.urlopen(req, context=ssl_context) as response:
                with open(output_file, 'wb') as f:
                    f.write(response.read())
        
        return True
        
    except Exception as e:
        print(f"  Error downloading {output_file}: {e}")
        return False

# Download TSP files
print("\nDownloading TSP instances...")
for name, url in tsp_urls.items():
    output_file = f'tsp_data/{name}.tsp'
    if not os.path.exists(output_file):
        print(f"  Downloading {name}...")
        if download_and_extract(url, output_file):
            print(f"    Success: {name}.tsp")
    else:
        print(f"  Already exists: {name}.tsp")

# Download QAP files
print("\nDownloading QAP instances...")
for name, url in qap_urls.items():
    output_file = f'qap_data/{name}.dat'
    if not os.path.exists(output_file):
        print(f"  Downloading {name}...")
        if download_and_extract(url, output_file):
            print(f"    Success: {name}.dat")
    else:
        print(f"  Already exists: {name}.dat")

print("\nDownload process complete!")
# Out:
# Downloading problem instances...
#
# Downloading TSP instances...
#   Already exists: eil51.tsp
#   Already exists: berlin52.tsp
#   Already exists: st70.tsp
#   Already exists: pr76.tsp
#   Already exists: eil101.tsp
#   Already exists: ch130.tsp
#   Already exists: tsp225.tsp
#   Already exists: a280.tsp
#   Already exists: lin318.tsp
#   Already exists: pcb442.tsp
#   Already exists: att532.tsp
#   Already exists: rat575.tsp
#   Already exists: rat783.tsp
#   Already exists: pr1002.tsp
#   Already exists: u1060.tsp
#   Already exists: vm1084.tsp
#   Already exists: pcb1173.tsp
#   Already exists: d1291.tsp
#
# Downloading QAP instances...
#   Already exists: tai12a.dat
#   Already exists: tai15a.dat
#   Already exists: nug12.dat
#   Already exists: chr12a.dat
#   Already exists: tai20a.dat
#   Already exists: tai25a.dat
#   Already exists: tai30a.dat
#   Already exists: tai35a.dat
#   Already exists: tai40a.dat
#   Already exists: tai50a.dat
#   Already exists: tai60a.dat
#   Already exists: tai80a.dat
#   Already exists: tai100a.dat
#   Already exists: nug20.dat
#   Already exists: nug30.dat
#   Already exists: sko42.dat
#   Already exists: sko49.dat
#   Already exists: sko56.dat
#   Already exists: sko64.dat
#   Already exists: sko72.dat
#   Already exists: sko81.dat
#   Already exists: sko90.dat
#   Already exists: sko100a.dat
#   Already exists: wil50.dat
#   Already exists: wil100.dat
#   Already exists: tho30.dat
#   Already exists: tho40.dat
#   Already exists: tho150.dat
#   Already exists: chr20a.dat
#
# Download process complete!

# %%
# @title Define Problem Classes

@dataclass
class TSPProblem:
    """Travelling Salesman Problem class"""
    coordinates: np.ndarray
    name: str = ""

    def __post_init__(self):
        self.n_cities = len(self.coordinates)
        self.distance_matrix = self._compute_distance_matrix()
        self.optimal_solution = self._get_optimal_solution()

    def _compute_distance_matrix(self) -> np.ndarray:
        """Compute Euclidean distance matrix"""
        distances = np.zeros((self.n_cities, self.n_cities))
        for i in range(self.n_cities):
            for j in range(i+1, self.n_cities):
                dist = np.linalg.norm(self.coordinates[i] - self.coordinates[j])
                distances[i][j] = dist
                distances[j][i] = dist
        return distances

    def _get_optimal_solution(self) -> float:
        """Return known optimal solution"""
        optimal_solutions = {
            # Original instances
            'eil51': 426,
            'berlin52': 7542,
            'st70': 675,
            'pr76': 108159,
            
            # Harder TSP instances
            'eil101': 629,
            'ch130': 6110,
            'tsp225': 3916,
            'a280': 2579,
            'lin318': 42029,
            'pcb442': 50778,
            'att532': 27686,
            'rat575': 6773,
            'rat783': 8806,
            'pr1002': 259045,
            'u1060': 224094,
            'vm1084': 239297,
            'pcb1173': 56892,
            'd1291': 50801,
        }
    
        return optimal_solutions.get(self.name, None)

    def evaluate(self, tour: List[int]) -> float:
        """Calculate total tour length"""
        total_distance = 0.0
        for i in range(len(tour) - 1):
            total_distance += self.distance_matrix[tour[i]][tour[i+1]]
        total_distance += self.distance_matrix[tour[-1]][tour[0]]
        return total_distance

    def get_fitness(self, tour: List[int]) -> float:
        """Convert cost to fitness (for GA)"""
        return 1.0 / (self.evaluate(tour) + 1e-10)

@dataclass
class QAPProblem:
    """Quadratic Assignment Problem class"""
    flow_matrix: np.ndarray
    distance_matrix: np.ndarray
    name: str = ""

    def __post_init__(self):
        self.n = len(self.flow_matrix)
        self.optimal_solution = self._get_optimal_solution()

    def _get_optimal_solution(self) -> float:
        """Return known optimal solution"""
        
        optimal_solutions = {
           # Original instances
            'tai12a': 224416,
            'tai15a': 388214,
            'nug12': 578,
            'chr12a': 9552,
            
            # Harder QAP instances
            'tai20a': 703482,
            'tai25a': 1167256,
            'tai30a': 1818146,
            'tai35a': 2422002,
            'tai40a': 3139370,
            'tai50a': 4588212,
            'tai60a': 7205962,
            'tai80a': 13499184,
            'tai100a': 21052466,
            'nug20': 2570,
            'nug30': 6124,
            'sko42': 15812,
            'sko49': 23386,
            'sko56': 34458,
            'sko64': 48498,
            'sko72': 66256,
            'sko81': 90998,
            'sko90': 115534,
            'sko100a': 152002,
            'wil50': 48816,
            'wil100': 273038,
            'tho30': 149936,
            'tho40': 240516,
            'tho150': 8133398,
            'chr20a': 2192,
        }
        return optimal_solutions.get(self.name, None)

    def evaluate(self, assignment: List[int]) -> float:
        """Calculate total assignment cost"""
        total_cost = 0.0
        for i in range(self.n):
            for j in range(self.n):
                total_cost += self.flow_matrix[i][j] * \
                             self.distance_matrix[assignment[i]][assignment[j]]
        return total_cost

    def get_fitness(self, assignment: List[int]) -> float:
        """Convert cost to fitness (for GA)"""
        return 1.0 / (self.evaluate(assignment) + 1e-10)

print("Problem classes defined successfully")
# Out:
# Problem classes defined successfully

# %%
# @title Load Problem Instances

def load_tsp_instance(filename: str, name: str) -> TSPProblem:
    """Load TSP instance from file"""
    coordinates = []
    reading_coords = False

    with open(filename, 'r') as f:
        for line in f:
            line = line.strip()
            if line.startswith('NODE_COORD_SECTION'):
                reading_coords = True
                continue
            if line == 'EOF' or line.startswith('DISPLAY_DATA_SECTION'):
                break
            if reading_coords and line:
                parts = line.split()
                if len(parts) >= 3 and parts[0].isdigit():
                    coordinates.append([float(parts[1]), float(parts[2])])

    coords_array = np.array(coordinates)
    return TSPProblem(coords_array, name)

def load_qap_instance(filename: str, name: str) -> QAPProblem:
    """Load QAP instance from file"""
    with open(filename, 'r') as f:
        lines = f.readlines()

    # Parse the file
    n = int(lines[0].strip())

    # Skip blank lines and comments
    data_lines = []
    for line in lines[1:]:
        line = line.strip()
        if line and not line.startswith('#'):
            data_lines.extend(line.split())

    # Convert to integers
    data = list(map(int, data_lines))

    # Extract flow and distance matrices
    flow_matrix = np.zeros((n, n))
    distance_matrix = np.zeros((n, n))

    idx = 0
    for i in range(n):
        for j in range(n):
            flow_matrix[i][j] = data[idx]
            idx += 1

    for i in range(n):
        for j in range(n):
            distance_matrix[i][j] = data[idx]
            idx += 1

    return QAPProblem(flow_matrix, distance_matrix, name)

# Load all instances
print("Loading problem instances...")

tsp_instances = {}
tsp_files = {
    # Original instances
    'eil51': 'tsp_data/eil51.tsp',
    'berlin52': 'tsp_data/berlin52.tsp',
    'st70': 'tsp_data/st70.tsp',
    'pr76': 'tsp_data/pr76.tsp',
    
    # Harder TSP instances
    'eil101': 'tsp_data/eil101.tsp',
    'ch130': 'tsp_data/ch130.tsp',
    'tsp225': 'tsp_data/tsp225.tsp',
    'a280': 'tsp_data/a280.tsp',
    'lin318': 'tsp_data/lin318.tsp',
    'pcb442': 'tsp_data/pcb442.tsp',
    'att532': 'tsp_data/att532.tsp',
    'rat575': 'tsp_data/rat575.tsp',
    'rat783': 'tsp_data/rat783.tsp',
    'pr1002': 'tsp_data/pr1002.tsp',
    'u1060': 'tsp_data/u1060.tsp',
    'vm1084': 'tsp_data/vm1084.tsp',
    'pcb1173': 'tsp_data/pcb1173.tsp',
    'd1291': 'tsp_data/d1291.tsp',
}

print("\nTSP Instances:")
for name, filepath in tsp_files.items():
    if os.path.exists(filepath):
        tsp_instances[name] = load_tsp_instance(filepath, name)
        print(f"  Loaded {name}: {tsp_instances[name].n_cities} cities, "
              f"optimal={tsp_instances[name].optimal_solution}")
    else:
        print(f"  Not found: {filepath}")

qap_instances = {}

qap_files = {
    # Original instances
    'tai12a': 'qap_data/tai12a.dat',
    'tai15a': 'qap_data/tai15a.dat',
    'nug12': 'qap_data/nug12.dat',
    'chr12a': 'qap_data/chr12a.dat',
    
    # Harder QAP instances
    'tai20a': 'qap_data/tai20a.dat',
    'tai25a': 'qap_data/tai25a.dat',
    'tai30a': 'qap_data/tai30a.dat',
    'tai35a': 'qap_data/tai35a.dat',
    'tai40a': 'qap_data/tai40a.dat',
    'tai50a': 'qap_data/tai50a.dat',
    'tai60a': 'qap_data/tai60a.dat',
    'tai80a': 'qap_data/tai80a.dat',
    'tai100a': 'qap_data/tai100a.dat',
    'nug20': 'qap_data/nug20.dat',
    'nug30': 'qap_data/nug30.dat',
    'sko42': 'qap_data/sko42.dat',
    'sko49': 'qap_data/sko49.dat',
    'sko56': 'qap_data/sko56.dat',
    'sko64': 'qap_data/sko64.dat',
    'sko72': 'qap_data/sko72.dat',
    'sko81': 'qap_data/sko81.dat',
    'sko90': 'qap_data/sko90.dat',
    'sko100a': 'qap_data/sko100a.dat',
    'wil50': 'qap_data/wil50.dat',
    'wil100': 'qap_data/wil100.dat',
    'tho30': 'qap_data/tho30.dat',
    'tho40': 'qap_data/tho40.dat',
    'tho150': 'qap_data/tho150.dat',
    'chr20a': 'qap_data/chr20a.dat',
}

print("\nQAP Instances:")
for name, filepath in qap_files.items():
    if os.path.exists(filepath):
        qap_instances[name] = load_qap_instance(filepath, name)
        print(f"  Loaded {name}: {qap_instances[name].n} facilities, "
              f"optimal={qap_instances[name].optimal_solution}")
    else:
        print(f"  Not found: {filepath}")

print("\nAll instances loaded successfully")
# Out:
# Loading problem instances...
#
# TSP Instances:
#   Loaded eil51: 51 cities, optimal=426
#   Loaded berlin52: 52 cities, optimal=7542
#   Loaded st70: 70 cities, optimal=675
#   Loaded pr76: 76 cities, optimal=108159
#   Loaded eil101: 101 cities, optimal=629
#   Loaded ch130: 130 cities, optimal=6110
#   Loaded tsp225: 225 cities, optimal=3916
#   Loaded a280: 280 cities, optimal=2579
#   Loaded lin318: 318 cities, optimal=42029
#   Loaded pcb442: 442 cities, optimal=50778
#   Loaded att532: 532 cities, optimal=27686
#   Loaded rat575: 575 cities, optimal=6773
#   Loaded rat783: 783 cities, optimal=8806
#   Loaded pr1002: 1002 cities, optimal=259045
#   Loaded u1060: 1060 cities, optimal=224094
#   Loaded vm1084: 1084 cities, optimal=239297
#   Loaded pcb1173: 1173 cities, optimal=56892
#   Loaded d1291: 1291 cities, optimal=50801
#
# QAP Instances:
#   Loaded tai12a: 12 facilities, optimal=224416
#   Loaded tai15a: 15 facilities, optimal=388214
#   Loaded nug12: 12 facilities, optimal=578
#   Loaded chr12a: 12 facilities, optimal=9552
#   Loaded tai20a: 20 facilities, optimal=703482
#   Loaded tai25a: 25 facilities, optimal=1167256
#   Loaded tai30a: 30 facilities, optimal=1818146
#   Loaded tai35a: 35 facilities, optimal=2422002
#   Loaded tai40a: 40 facilities, optimal=3139370
#   Loaded tai50a: 50 facilities, optimal=4588212
#   Loaded tai60a: 60 facilities, optimal=7205962
#   Loaded tai80a: 80 facilities, optimal=13499184
#   Loaded tai100a: 100 facilities, optimal=21052466
#   Loaded nug20: 20 facilities, optimal=2570
#   Loaded nug30: 30 facilities, optimal=6124
#   Loaded sko42: 42 facilities, optimal=15812
#   Loaded sko49: 49 facilities, optimal=23386
#   Loaded sko56: 56 facilities, optimal=34458
#   Loaded sko64: 64 facilities, optimal=48498
#   Loaded sko72: 72 facilities, optimal=66256
#   Loaded sko81: 81 facilities, optimal=90998
#   Loaded sko90: 90 facilities, optimal=115534
#   Loaded sko100a: 100 facilities, optimal=152002
#   Loaded wil50: 50 facilities, optimal=48816
#   Loaded wil100: 100 facilities, optimal=273038
#   Loaded tho30: 30 facilities, optimal=149936
#   Loaded tho40: 40 facilities, optimal=240516
#   Loaded tho150: 150 facilities, optimal=8133398
#   Loaded chr20a: 20 facilities, optimal=2192
#
# All instances loaded successfully

# %%
# @title Genetic Algorithm Implementation

class GeneticAlgorithm:
    """Optimized Genetic Algorithm with Integrated 2-Opt and Full Elitism"""

    def __init__(self,
                 problem: Any,
                 population_size: int = 100,
                 max_generations: int = 500,
                 mutation_rate: float = 0.15, # Slightly raised to boost diversity
                 crossover_rate: float = 0.9,
                 elitism_count: int = 2,
                 tournament_size: int = 3,
                 verbose: bool = True):

        self.problem = problem
        self.population_size = population_size
        self.max_generations = max_generations
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.elitism_count = elitism_count
        self.tournament_size = tournament_size
        self.verbose = verbose

        self.population = []
        self.fitness_history = []
        self.best_solution = None
        self.best_cost = float('inf')
        self.convergence_generation = 0

    def _is_tsp(self) -> bool:
        return isinstance(self.problem, TSPProblem)

    def _get_problem_size(self) -> int:
        return self.problem.n_cities if self._is_tsp() else self.problem.n

    def initialize_population(self):
        """Initialize population with random permutations"""
        self.population = []
        problem_size = self._get_problem_size()

        for _ in range(self.population_size):
            individual = list(range(problem_size))
            random.shuffle(individual)
            self.population.append(individual)

    def calculate_fitness(self) -> List[float]:
        """Calculate fitness for entire population"""
        # Ensure your fitness evaluator accurately reflects lower costs as higher values
        return [self.problem.get_fitness(ind) for ind in self.population]

    def tournament_selection(self, fitness_scores: List[float]) -> List[List[int]]:
        """Select individuals using tournament selection"""
        selected = []
        for _ in range(self.population_size):
            tournament_indices = random.sample(range(self.population_size), self.tournament_size)
            best_idx = max(tournament_indices, key=lambda i: fitness_scores[i])
            selected.append(self.population[best_idx].copy())
        return selected

    def order_crossover(self, parent1: List[int], parent2: List[int]) -> Tuple[List[int], List[int]]:
        """Order Crossover (OX) for TSP running in clear O(N) time"""
        size = len(parent1)
        child1 = [-1] * size
        child2 = [-1] * size

        point1, point2 = sorted(random.sample(range(size), 2))

        child1[point1:point2] = parent1[point1:point2]
        child2[point1:point2] = parent2[point1:point2]

        # Track filled set elements to keep lookup times at O(1) instead of linear array scans
        set1 = set(child1[point1:point2])
        set2 = set(child2[point1:point2])

        self._fill_remaining_ox_fast(child1, parent2, point2, set1)
        self._fill_remaining_ox_fast(child2, parent1, point2, set2)

        return child1, child2

    def _fill_remaining_ox_fast(self, child: List[int], parent: List[int], point2: int, existing_elements: set):
        """O(N) position assignment helper"""
        size = len(child)
        current_pos = point2 % size

        for i in range(size):
            item = parent[(point2 + i) % size]
            if item not in existing_elements:
                child[current_pos] = item
                current_pos = (current_pos + 1) % size

    def pmx_crossover(self, parent1: List[int], parent2: List[int]) -> Tuple[List[int], List[int]]:
        """Partially Mapped Crossover (PMX) for QAP"""
        size = len(parent1)
        child1 = parent1.copy()
        child2 = parent2.copy()

        point1, point2 = sorted(random.sample(range(size), 2))

        mapping1 = {}
        mapping2 = {}

        for i in range(point1, point2):
            val1, val2 = child1[i], child2[i]
            child1[i], child2[i] = val2, val1
            mapping1[val2] = val1
            mapping2[val1] = val2

        self._fix_duplicates_pmx(child1, mapping1, point1, point2)
        self._fix_duplicates_pmx(child2, mapping2, point1, point2)

        return child1, child2

    def _fix_duplicates_pmx(self, child: List[int], mapping: Dict[int, int], point1: int, point2: int):
        for i in range(len(child)):
            if point1 <= i < point2:
                continue
            while child[i] in mapping:
                child[i] = mapping[child[i]]

    def crossover(self, parent1: List[int], parent2: List[int]) -> Tuple[List[int], List[int]]:
        if random.random() > self.crossover_rate:
            return parent1.copy(), parent2.copy()

        return self.order_crossover(parent1, parent2) if self._is_tsp() else self.pmx_crossover(parent1, parent2)

    def mutate(self, individual: List[int]) -> List[int]:
        """Apply mutation operator based directly on mutation_rate threshold"""
        mutated = individual.copy()
        if random.random() < self.mutation_rate:
            if random.random() < 0.5:
                # Swap Mutation
                idx1, idx2 = random.sample(range(len(mutated)), 2)
                mutated[idx1], mutated[idx2] = mutated[idx2], mutated[idx1]
            else:
                # Inversion Mutation
                idx1, idx2 = sorted(random.sample(range(len(mutated)), 2))
                mutated[idx1:idx2+1] = list(reversed(mutated[idx1:idx2+1]))
        return mutated

    def _two_opt(self, tour: List[int], current_cost: float) -> Tuple[List[int], float]:
        """Untangle intersecting segments to accelerate global minimum convergence"""
        best_tour = tour.copy()
        best_cost = current_cost
        size = len(tour)

        # For TSP, score each candidate move via an O(1) distance-matrix delta
        # instead of a full O(n) tour re-evaluation. Same accepted moves, same
        # final result -- just skips redundant summation. QAP keeps full
        # evaluate() since its instances are small enough that it's already cheap.
        use_delta = self._is_tsp()
        if use_delta:
            D = self.problem.distance_matrix

        max_attempts = 2
        attempts = 0
        improved = True

        while improved and attempts < max_attempts:
            improved = False
            attempts += 1
            for i in range(1, size - 2):
                for j in range(i + 1, size):
                    if j - i == 1: continue

                    if use_delta:
                        a, b = best_tour[i - 1], best_tour[i]
                        c, d = best_tour[j - 1], best_tour[j]
                        delta = (D[a][c] + D[b][d]) - (D[a][b] + D[c][d])
                        if delta < 0:
                            new_tour = best_tour.copy()
                            new_tour[i:j] = best_tour[i:j][::-1]
                            best_tour = new_tour
                            best_cost = best_cost + delta
                            improved = True
                    else:
                        new_tour = best_tour.copy()
                        new_tour[i:j] = best_tour[i:j][::-1]

                        new_cost = self.problem.evaluate(new_tour)
                        if new_cost < best_cost:
                            best_tour = new_tour
                            best_cost = new_cost
                            improved = True
            if not improved:
                break
        return best_tour, best_cost

    def evolve(self) -> Tuple[List[int], float]:
        """Main execution evolution loop"""
        self.initialize_population()

        for generation in range(self.max_generations):
            fitness_scores = self.calculate_fitness()

            # Identify current generation champions
            sorted_indices = np.argsort(fitness_scores)[::-1] # Highest fitness first
            best_idx = sorted_indices[0]
            current_cost = self.problem.evaluate(self.population[best_idx])

            # Apply 2-opt only when this generation's best beats the global best
            # (reverted from every-generation: caused premature convergence /
            # diversity collapse on rugged landscapes, e.g. chr12a, nug12)
            if current_cost < self.best_cost:
                optimized_tour, optimized_cost = self._two_opt(self.population[best_idx], current_cost)
                self.population[best_idx] = optimized_tour
                self.best_cost = optimized_cost
                self.best_solution = optimized_tour.copy()
                self.convergence_generation = generation

            self.fitness_history.append(self.best_cost)

            # Save top performing elite parents
            elites = [self.population[idx].copy() for idx in sorted_indices[:self.elitism_count]]

            # Selection step
            selected = self.tournament_selection(fitness_scores)
            new_population = []

            # Crossbreed phase
            for i in range(0, self.population_size - self.elitism_count, 2):
                p1 = selected[i]
                p2 = selected[min(i+1, len(selected)-1)]

                c1, c2 = self.crossover(p1, p2)
                new_population.append(self.mutate(c1))
                new_population.append(self.mutate(c2))

            # Combine elites back into active population
            self.population = elites + new_population[:self.population_size - self.elitism_count]

            if self.verbose and (generation + 1) % 50 == 0:
                print(f"Generation {generation+1}/{self.max_generations} - Best Cost: {self.best_cost:.4f}")

        return self.best_solution, self.best_cost

print("Genetic Algorithm implementation complete")
# Out:
# Genetic Algorithm implementation complete

# %%
# @title Differential Evolution Implementation

class DifferentialEvolution:
    """Fast Continuous Differential Evolution with 2-Opt Local Search for TSP/QAP"""

    def __init__(self,
                 problem: Any,
                 population_size: int = 100,
                 max_generations: int = 500,
                 F: float = 0.8,
                 CR: float = 0.9,
                 strategy: str = 'rand/1/bin',
                 verbose: bool = True):

        self.problem = problem
        self.population_size = population_size
        self.max_generations = max_generations
        self.F = F  # Mutation factor
        self.CR = CR  # Crossover rate
        self.strategy = strategy
        self.verbose = verbose

        self.population = None
        self.fitness = None
        self.best_solution = None
        self.best_cost = float('inf')
        self.convergence_generation = 0
        self.fitness_history = [] # Added fitness_history

    def _is_tsp(self) -> bool:
        return isinstance(self.problem, TSPProblem)

    def _get_problem_size(self) -> int:
        return self.problem.n_cities if self._is_tsp() else self.problem.n

    def _vector_to_permutation(self, vector: np.ndarray) -> List[int]:
        """Converts continuous vector to a valid discrete permutation route via sorting"""
        return list(np.argsort(vector))

    def _permutation_to_vector(self, perm: List[int]) -> np.ndarray:
        """Converts a discrete route into a normalized continuous vector"""
        vector = np.zeros(len(perm))
        for rank, city in enumerate(perm):
            vector[city] = rank / len(perm)
        return vector

    def initialize_population(self):
        """Initialize population using numpy for high speed"""
        problem_size = self._get_problem_size()

        self.population = np.random.rand(self.population_size, problem_size)
        self.fitness = np.zeros(self.population_size)

        greedy_perm = self._greedy_initialization()
        self.population[0] = self._permutation_to_vector(greedy_perm)

        for i in range(self.population_size):
            perm = self._vector_to_permutation(self.population[i])
            self.fitness[i] = self.problem.evaluate(perm)

            if self.fitness[i] < self.best_cost:
                self.best_cost = self.fitness[i]
                self.best_solution = perm

    def _greedy_initialization(self) -> List[int]:
        """Greedy initialization using nearest neighbor"""
        problem_size = self._get_problem_size()
        start_city = random.randint(0, problem_size - 1)
        tour = [start_city]
        unvisited = set(range(problem_size))
        unvisited.remove(start_city)

        while unvisited:
            current = tour[-1]
            if self._is_tsp():
                nearest = min(unvisited, key=lambda x: self.problem.distance_matrix[current][x])
            else:
                nearest = min(unvisited, key=lambda x: self.problem.flow_matrix[current][x])
            tour.append(nearest)
            unvisited.remove(nearest)
        return tour

    def _two_opt(self, tour: List[int], current_cost: float) -> Tuple[List[int], float]:
        """Performs a 2-opt local search to untangle crossing paths"""
        best_tour = tour.copy()
        best_cost = current_cost
        size = len(tour)
        improved = True

        # For TSP, score each candidate move via an O(1) distance-matrix delta
        # instead of a full O(n) tour re-evaluation. Same accepted moves, same
        # final result -- just skips redundant summation. QAP keeps full
        # evaluate() since its instances are small enough that it's already cheap.
        use_delta = self._is_tsp()
        if use_delta:
            D = self.problem.distance_matrix

        # Limit total steps to ensure it doesn't loop infinitely on messy paths
        max_attempts = 2
        attempts = 0

        while improved and attempts < max_attempts:
            improved = False
            attempts += 1
            for i in range(1, size - 2):
                for j in range(i + 1, size):
                    if j - i == 1: continue # Skip adjacent cities

                    if use_delta:
                        a, b = best_tour[i - 1], best_tour[i]
                        c, d = best_tour[j - 1], best_tour[j]
                        delta = (D[a][c] + D[b][d]) - (D[a][b] + D[c][d])
                        if delta < 0:
                            new_tour = best_tour.copy()
                            new_tour[i:j] = best_tour[i:j][::-1]
                            best_tour = new_tour
                            best_cost = best_cost + delta
                            improved = True
                    else:
                        # Reverse the segment between i and j
                        new_tour = best_tour.copy()
                        new_tour[i:j] = best_tour[i:j][::-1]

                        new_cost = self.problem.evaluate(new_tour)
                        if new_cost < best_cost:
                            best_tour = new_tour
                            best_cost = new_cost
                            improved = True
            if not improved:
                break
        return best_tour, best_cost

    def evolve(self):
        """Main optimization loop"""
        problem_size = self._get_problem_size()
        self.initialize_population()

        for gen in range(self.max_generations):
            for i in range(self.population_size):
                # 1. Mutation via array slicing
                candidates = [idx for idx in range(self.population_size) if idx != i]

                if self.strategy == 'rand/1/bin':
                    r1, r2, r3 = random.sample(candidates, 3)
                    mutant = self.population[r1] + self.F * (self.population[r2] - self.population[r3])
                elif self.strategy == 'best/1/bin':
                    best_idx = np.argmin(self.fitness)
                    r1, r2 = random.sample(candidates, 2)
                    mutant = self.population[best_idx] + self.F * (self.population[r1] - self.population[r2])
                else:
                    best_idx = np.argmin(self.fitness)
                    r1, r2 = random.sample(candidates, 2)
                    mutant = self.population[i] + self.F * (self.population[best_idx] - self.population[i]) + self.F * (self.population[r1] - self.population[r2])

                mutant = np.clip(mutant, 0, 1)

                # 2. Fast Binomial Crossover
                cross_mask = np.random.rand(problem_size) < self.CR
                cross_mask[random.randint(0, problem_size - 1)] = True

                trial = np.where(cross_mask, mutant, self.population[i])

                # 3. Selection
                trial_perm = self._vector_to_permutation(trial)
                trial_cost = self.problem.evaluate(trial_perm)

                if trial_cost <= self.fitness[i]:
                    self.population[i] = trial
                    self.fitness[i] = trial_cost

                    # Apply 2-opt only when this trial beats the global best
                    # (reverted from every-generation: caused premature
                    # convergence / diversity collapse on rugged landscapes,
                    # e.g. chr12a, nug12)
                    if trial_cost < self.best_cost:
                        optimized_perm, optimized_cost = self._two_opt(trial_perm, trial_cost)
                        self.population[i] = self._permutation_to_vector(optimized_perm)
                        self.fitness[i] = optimized_cost
                        self.best_cost = optimized_cost
                        self.best_solution = optimized_perm
                        self.convergence_generation = gen

            # Append the current best cost AFTER this generation's updates
            self.fitness_history.append(self.best_cost)

            if self.verbose and (gen + 1) % 50 == 0:
                print(f"Generation {gen+1}/{self.max_generations} - Best Cost: {self.best_cost:.4f}")

        return self.best_solution, self.best_cost

print("Differential Evolution implementation complete!")
# Out:
# Differential Evolution implementation complete!

# %%
# @title Experiment Runner and Analysis

class ExperimentRunner:
    """Run experiments comparing GA and DE"""

    def __init__(self, problem: Any, problem_name: str):
        self.problem = problem
        self.problem_name = problem_name
        self.results = {
            'GA': {'costs': [], 'times': [], 'convergence': [], 'solutions': []},
            'DE': {'costs': [], 'times': [], 'convergence': [], 'solutions': []}
        }

    def run_single_experiment(self, algorithm: str, **params) -> Dict[str, Any]:
        """Run single experiment with given algorithm"""
        start_time = time.time()

        if algorithm == 'GA':
            algo = GeneticAlgorithm(self.problem, **params)
        else:
            algo = DifferentialEvolution(self.problem, **params)

        best_solution, best_cost = algo.evolve()

        end_time = time.time()
        execution_time = end_time - start_time

        return {
            'best_solution': best_solution,
            'best_cost': best_cost,
            'execution_time': execution_time,
            'convergence_history': algo.fitness_history,
            'convergence_generation': algo.convergence_generation
        }

    def run_multiple_experiments(self, num_runs: int = 5, **params) -> Dict[str, Any]:
        """Run multiple experiments for statistical analysis"""
        ga_params = params.get('ga_params', {})
        de_params = params.get('de_params', {})

        print(f"\n{'='*60}")
        print(f"Running {num_runs} experiments for {self.problem_name}")
        print(f"{'='*60}")

        for run in range(num_runs):
            print(f"\n▶ Run {run + 1}/{num_runs}")

            # Run GA
            print("  Running GA...", end=' ')
            ga_result = self.run_single_experiment('GA', **ga_params)
            self.results['GA']['costs'].append(ga_result['best_cost'])
            self.results['GA']['times'].append(ga_result['execution_time'])
            self.results['GA']['convergence'].append(ga_result['convergence_history'])
            self.results['GA']['solutions'].append(ga_result['best_solution'])
            print(f"✓ Best: {ga_result['best_cost']:.2f}")

            # Run DE
            print("  Running DE...", end=' ')
            de_result = self.run_single_experiment('DE', **de_params)
            self.results['DE']['costs'].append(de_result['best_cost'])
            self.results['DE']['times'].append(de_result['execution_time'])
            self.results['DE']['convergence'].append(de_result['convergence_history'])
            self.results['DE']['solutions'].append(de_result['best_solution'])
            print(f"✓ Best: {de_result['best_cost']:.2f}")

        return self.results

    def calculate_statistics(self) -> pd.DataFrame:
        """Calculate statistical measures"""
        stats_data = []

        for algorithm in ['GA', 'DE']:
            costs = self.results[algorithm]['costs']
            times = self.results[algorithm]['times']

            optimal_gap = None
            if self.problem.optimal_solution:
                optimal_gap = ((np.mean(costs) - self.problem.optimal_solution) /
                              self.problem.optimal_solution * 100)

            stats_data.append({
                'Algorithm': algorithm,
                'Mean Cost': f"{np.mean(costs):.2f}",
                'Std Dev': f"{np.std(costs):.2f}",
                'Best Cost': f"{np.min(costs):.2f}",
                'Worst Cost': f"{np.max(costs):.2f}",
                'Mean Time (s)': f"{np.mean(times):.3f}",
                'Optimal': f"{self.problem.optimal_solution}" if self.problem.optimal_solution else "N/A",
                'Optimal Gap (%)': f"{optimal_gap:.3f}" if optimal_gap is not None else "N/A"
            })

        return pd.DataFrame(stats_data)

    def perform_statistical_test(self) -> Dict[str, float]:
        """Perform t-test to compare algorithms"""
        t_stat, p_value = stats.ttest_ind(
            self.results['GA']['costs'],
            self.results['DE']['costs']
        )

        return {
            't_statistic': t_stat,
            'p_value': p_value,
            'significant': p_value < 0.05
        }

    def plot_convergence_curves(self):
        """Plot convergence curves for both algorithms"""
        fig, axes = plt.subplots(1, 2, figsize=(15, 5))

        # GA convergence
        ax1 = axes[0]
        for history in self.results['GA']['convergence']:
            ax1.plot(history, alpha=0.3, color='blue', linewidth=0.5)

        max_len = max(len(h) for h in self.results['GA']['convergence'])
        mean_history = np.zeros(max_len)
        for history in self.results['GA']['convergence']:
            padded = np.pad(history, (0, max_len - len(history)), 'edge')
            mean_history += padded
        mean_history /= len(self.results['GA']['convergence'])

        ax1.plot(mean_history, color='blue', linewidth=2, label='Mean')
        ax1.axhline(y=self.problem.optimal_solution, color='green',
                   linestyle='--', label='Optimal', alpha=0.7)
        ax1.set_xlabel('Generation')
        ax1.set_ylabel('Best Cost')
        ax1.set_title(f'GA Convergence - {self.problem_name}')
        ax1.legend()
        ax1.grid(True, alpha=0.3)

        # DE convergence
        ax2 = axes[1]
        for history in self.results['DE']['convergence']:
            ax2.plot(history, alpha=0.3, color='red', linewidth=0.5)

        max_len = max(len(h) for h in self.results['DE']['convergence'])
        mean_history = np.zeros(max_len)
        for history in self.results['DE']['convergence']:
            padded = np.pad(history, (0, max_len - len(history)), 'edge')
            mean_history += padded
        mean_history /= len(self.results['DE']['convergence'])

        ax2.plot(mean_history, color='red', linewidth=2, label='Mean')
        ax2.axhline(y=self.problem.optimal_solution, color='green',
                   linestyle='--', label='Optimal', alpha=0.7)
        ax2.set_xlabel('Generation')
        ax2.set_ylabel('Best Cost')
        ax2.set_title(f'DE Convergence - {self.problem_name}')
        ax2.legend()
        ax2.grid(True, alpha=0.3)

        plt.suptitle(f'Convergence Analysis - {self.problem_name}', fontsize=14)
        plt.tight_layout()
        plt.show()

    def plot_comparison_boxplots(self):
        """Plot boxplots comparing algorithm performance"""
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))

        # Cost comparison
        ax1 = axes[0]
        data = [self.results['GA']['costs'], self.results['DE']['costs']]
        bp1 = ax1.boxplot(data, labels=['GA', 'DE'], patch_artist=True)
        bp1['boxes'][0].set_facecolor('lightblue')
        bp1['boxes'][1].set_facecolor('lightcoral')
        ax1.set_ylabel('Best Cost')
        ax1.set_title('Cost Distribution')
        ax1.grid(True, alpha=0.3)

        # Time comparison
        ax2 = axes[1]
        data = [self.results['GA']['times'], self.results['DE']['times']]
        bp2 = ax2.boxplot(data, labels=['GA', 'DE'], patch_artist=True)
        bp2['boxes'][0].set_facecolor('lightblue')
        bp2['boxes'][1].set_facecolor('lightcoral')
        ax2.set_ylabel('Execution Time (s)')
        ax2.set_title('Time Distribution')
        ax2.grid(True, alpha=0.3)

        # Optimal gap comparison
        ax3 = axes[2]
        if self.problem.optimal_solution:
            ga_gaps = [(c - self.problem.optimal_solution) / self.problem.optimal_solution * 100
                      for c in self.results['GA']['costs']]
            de_gaps = [(c - self.problem.optimal_solution) / self.problem.optimal_solution * 100
                      for c in self.results['DE']['costs']]
            data = [ga_gaps, de_gaps]
            bp3 = ax3.boxplot(data, labels=['GA', 'DE'], patch_artist=True)
            bp3['boxes'][0].set_facecolor('lightblue')
            bp3['boxes'][1].set_facecolor('lightcoral')
            ax3.set_ylabel('Optimality Gap (%)')
            ax3.set_title('Optimality Gap')
            ax3.grid(True, alpha=0.3)

        plt.suptitle(f'Performance Comparison - {self.problem_name}', fontsize=14)
        plt.tight_layout()
        plt.show()

print("Experiment runner ready")
# Out:
# Experiment runner ready

# %%
# @title Hyperaparameter Optimiztion


import numpy as np
import optuna
import logging
import json # Added for JSON serialization
import os   # Added for path operations
from typing import Dict, Any

# Mute Optuna's default verbose logging to preserve clean console outputs
optuna.logging.set_verbosity(optuna.logging.WARNING)

class SelfImprovingOptimizer:
    """Automated parameter tuning framework for hybrid metaheuristics"""

    def __init__(self, problem_instance: Any, problem_name: str):
        self.problem = problem_instance
        self.problem_name = problem_name
        self._is_tsp = hasattr(problem_instance, 'n_cities')

    def tune_genetic_algorithm(self, n_trials: int = 25) -> Dict[str, Any]:
        print(f"Tuning GA hyperparameters for {self.problem_name}...")

        def objective(trial):
            # Define smart categorical and continuous parameter boundaries
            params = {
                'population_size': trial.suggest_int('population_size', 100, 300, step=50),
                'max_generations': trial.suggest_int('max_generations', 300, 500, step=50),
                'mutation_rate': trial.suggest_float('mutation_rate', 0.01, 0.25),
                'crossover_rate': trial.suggest_float('crossover_rate', 0.75, 0.98),
                'elitism_count': trial.suggest_int('elitism_count', 2, 10),
                'tournament_size': trial.suggest_int('tournament_size', 3, 8),
                'verbose': False
            }

            # Average over repeats for a stable estimate, but report the running
            # mean after each repeat so the pruner can cut clearly-bad trials
            # short instead of always paying for all repeats.
            costs = []
            for repeat in range(3):
                ga = GeneticAlgorithm(self.problem, **params)
                _, best_cost = ga.evolve()
                costs.append(best_cost)

                trial.report(float(np.mean(costs)), step=repeat)
                if trial.should_prune():
                    raise optuna.TrialPruned()

            return float(np.mean(costs))

        pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=1, interval_steps=1)
        study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42), pruner=pruner)
        study.optimize(objective, n_trials=n_trials)

        # Format discovered parameters cleanly back for the ExperimentRunner structure
        best_params = study.best_params
        best_params['verbose'] = False
        return best_params

    def tune_differential_evolution(self, n_trials: int = 25) -> Dict[str, Any]:
        print(f"Tuning DE hyperparameters for {self.problem_name}...")

        def objective(trial):
            params = {
                'population_size': trial.suggest_int('population_size', 100, 300, step=50),
                'max_generations': trial.suggest_int('max_generations', 300, 500, step=50),
                'F': trial.suggest_float('F', 0.3, 1.0),
                'CR': trial.suggest_float('CR', 0.6, 0.95),
                'strategy': trial.suggest_categorical('strategy', ['rand/1/bin', 'best/1/bin']),
                'verbose': False
            }

            costs = []
            for repeat in range(3):
                de = DifferentialEvolution(self.problem, **params)
                _, best_cost = de.evolve()
                costs.append(best_cost)

                trial.report(float(np.mean(costs)), step=repeat)
                if trial.should_prune():
                    raise optuna.TrialPruned()

            return float(np.mean(costs))

        pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=1, interval_steps=1)
        study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42), pruner=pruner)
        study.optimize(objective, n_trials=n_trials)

        best_params = study.best_params
        best_params['verbose'] = False
        return best_params

# ==========================================================================================
# SELF-OPTIMIZING EXECUTION PIPELINE
# ==========================================================================================
def run_self_improving_benchmarks(tsp_instances, qap_instances):
    all_results = {}

    # Create a cache directory for optimized parameters
    cache_dir = 'optimized_params_cache'
    os.makedirs(cache_dir, exist_ok=True)

    # 1. Process TSP Instances
    print("=" * 60)
    print("RUNNING AUTO-TUNED TSP EXPERIMENTS")
    print("=" * 60)
    for name, instance in tsp_instances.items():
        tuner = SelfImprovingOptimizer(instance, name)

        ga_cache_file = os.path.join(cache_dir, f'{name}_ga_params.json')
        de_cache_file = os.path.join(cache_dir, f'{name}_de_params.json')

        tuned_ga_params = {}
        tuned_de_params = {}

        # Load GA parameters from cache if available
        if os.path.exists(ga_cache_file):
            print(f"Loading cached GA parameters for {name}...")
            with open(ga_cache_file, 'r') as f:
                tuned_ga_params = json.load(f)
        else:
            # Self-improve configurations for the specific landscape
            tuned_ga_params = tuner.tune_genetic_algorithm(n_trials=25)
            with open(ga_cache_file, 'w') as f:
                json.dump(tuned_ga_params, f, indent=2)

        # Load DE parameters from cache if available
        if os.path.exists(de_cache_file):
            print(f"Loading cached DE parameters for {name}...")
            with open(de_cache_file, 'r') as f:
                tuned_de_params = json.load(f)
        else:
            tuned_de_params = tuner.tune_differential_evolution(n_trials=25)
            with open(de_cache_file, 'w') as f:
                json.dump(tuned_de_params, f, indent=2)

        print(f"\nOptimal parameters identified for {name}!")
        print(f" > Tuned GA: MutRate={tuned_ga_params['mutation_rate']:.3f}, Elite={tuned_ga_params['elitism_count']}")
        print(f" > Tuned DE: Strategy={tuned_de_params['strategy']}, F={tuned_de_params['F']:.3f}")

        # Pass optimal parameters directly into execution runner
        runner = ExperimentRunner(instance, name)
        runner.run_multiple_experiments(num_runs=30, ga_params=tuned_ga_params, de_params=tuned_de_params)

        stats_df = runner.calculate_statistics()
        test_results = runner.perform_statistical_test()

        # Print Statistical Summary and T-test results
        print("\nStatistical Summary:")
        print(stats_df.to_string(index=False))
        t_stat = test_results.get('t_statistic', float('nan'))
        p_val = test_results.get('p_value', float('nan'))
        print(f"\nT-test: t={t_stat:.3f}, p={p_val:.4f}")

        # Print summary for the problem
        print(f"\n{name} completed:")
        print(f"  GA - Best: {min(runner.results['GA']['costs']):.2f}, ")
        print(f"  Mean: {np.mean(runner.results['GA']['costs']):.2f}")
        print(f"  DE - Best: {min(runner.results['DE']['costs']):.2f}, ")
        print(f"  Mean: {np.mean(runner.results['DE']['costs']):.2f}")

        all_results[name] = {
            'runner': runner, 'statistics': stats_df, 'test': test_results,
            'type': 'TSP',
            'best_ga_cost': min(runner.results['GA']['costs']), 'best_de_cost': min(runner.results['DE']['costs'])
        }

    # 2. Process QAP Instances
    print("\n" + "=" * 60)
    print("RUNNING AUTO-TUNED QAP EXPERIMENTS")
    print("=" * 60)
    for name, instance in qap_instances.items():
        tuner = SelfImprovingOptimizer(instance, name)

        ga_cache_file = os.path.join(cache_dir, f'{name}_ga_params.json')
        de_cache_file = os.path.join(cache_dir, f'{name}_de_params.json')

        tuned_ga_params = {}
        tuned_de_params = {}

        # Load GA parameters from cache if available
        if os.path.exists(ga_cache_file):
            print(f"Loading cached GA parameters for {name}...")
            with open(ga_cache_file, 'r') as f:
                tuned_ga_params = json.load(f)
        else:
            tuned_ga_params = tuner.tune_genetic_algorithm(n_trials=25)
            with open(ga_cache_file, 'w') as f:
                json.dump(tuned_ga_params, f, indent=2)

        # Load DE parameters from cache if available
        if os.path.exists(de_cache_file):
            print(f"Loading cached DE parameters for {name}...")
            with open(de_cache_file, 'r') as f:
                tuned_de_params = json.load(f)
        else:
            tuned_de_params = tuner.tune_differential_evolution(n_trials=25)
            with open(de_cache_file, 'w') as f:
                json.dump(tuned_de_params, f, indent=2)

        print(f"\nOptimal parameters identified for {name}!")
        print(f" > Tuned GA: MutRate={tuned_ga_params['mutation_rate']:.3f}, Elite={tuned_ga_params['elitism_count']}")
        print(f" > Tuned DE: Strategy={tuned_de_params['strategy']}, F={tuned_de_params['F']:.3f}")

        runner = ExperimentRunner(instance, name)
        runner.run_multiple_experiments(num_runs=30, ga_params=tuned_ga_params, de_params=tuned_de_params)

        stats_df = runner.calculate_statistics()
        test_results = runner.perform_statistical_test()

        # Print Statistical Summary and T-test results
        print("\nStatistical Summary:")
        print(stats_df.to_string(index=False))
        t_stat = test_results.get('t_statistic', float('nan'))
        p_val = test_results.get('p_value', float('nan'))
        print(f"\nT-test: t={t_stat:.3f}, p={p_val:.4f}")

        # Print summary for the problem
        print(f"\n{name} completed:")
        print(f"  GA - Best: {min(runner.results['GA']['costs']):.2f}, ")
        print(f"  Mean: {np.mean(runner.results['GA']['costs']):.2f}")
        print(f"  DE - Best: {min(runner.results['DE']['costs']):.2f}, ")
        print(f"  Mean: {np.mean(runner.results['DE']['costs']):.2f}")

        all_results[name] = {
            'runner': runner, 'statistics': stats_df, 'test': test_results,
            'type': 'QAP',
            'best_ga_cost': min(runner.results['GA']['costs']), 'best_de_cost': min(runner.results['DE']['costs'])
        }

    return all_results

# %%
# @title Create final summary
import json

def create_final_summary(all_results):
    """Create comprehensive summary of all experiments"""
    summary_data = []

    for problem_name, result in all_results.items():
        stats_df = result['statistics']
        problem_type = result['type']

        for _, row in stats_df.iterrows():
            summary_data.append({
                'Problem': problem_name,
                'Type': problem_type,
                'Algorithm': row['Algorithm'],
                'Mean Cost': row['Mean Cost'],
                'Best Cost': row['Best Cost'],
                'Std Dev': row['Std Dev'],
                'Optimal': row['Optimal'],
                'Optimal Gap (%)': row['Optimal Gap (%)'],
                'Mean Time (s)': row['Mean Time (s)']
            })

    summary_df = pd.DataFrame(summary_data)

    # Display summary
    print("\n" + "=" * 90)
    print("FINAL COMPREHENSIVE SUMMARY")
    print("=" * 90)
    print(summary_df.to_string(index=False))

    # Save to CSV
    summary_df.to_csv('experiment_results.csv', index=False)
    print("\nResults saved to 'experiment_results.csv'")

    return summary_df

def plot_final_comparison(all_results):
    """Generate comprehensive comparison plots"""
    # Separate TSP and QAP results
    tsp_names = [name for name, r in all_results.items() if r['type'] == 'TSP']
    qap_names = [name for name, r in all_results.items() if r['type'] == 'QAP']

    fig, axes = plt.subplots(2, 2, figsize=(15, 12))

    # TSP Results
    if tsp_names:
        ax1 = axes[0, 0]
        ga_means = []
        de_means = []

        for name in tsp_names:
            stats_df = all_results[name]['statistics']
            ga_means.append(float(stats_df[stats_df['Algorithm'] == 'GA']['Mean Cost'].iloc[0]))
            de_means.append(float(stats_df[stats_df['Algorithm'] == 'DE']['Mean Cost'].iloc[0]))

        x = np.arange(len(tsp_names))
        width = 0.35
        ax1.bar(x - width/2, ga_means, width, label='GA', color='lightblue')
        ax1.bar(x + width/2, de_means, width, label='DE', color='lightcoral')
        ax1.set_xlabel('TSP Instance')
        ax1.set_ylabel('Mean Best Cost')
        ax1.set_title('TSP Performance Comparison')
        ax1.set_xticks(x)
        ax1.set_xticklabels(tsp_names)
        ax1.legend()
        ax1.grid(True, alpha=0.3)

    # QAP Results
    if qap_names:
        ax2 = axes[0, 1]
        ga_means = []
        de_means = []

        for name in qap_names:
            stats_df = all_results[name]['statistics']
            ga_means.append(float(stats_df[stats_df['Algorithm'] == 'GA']['Mean Cost'].iloc[0]))
            de_means.append(float(stats_df[stats_df['Algorithm'] == 'DE']['Mean Cost'].iloc[0]))

        x = np.arange(len(qap_names))
        width = 0.35
        ax2.bar(x - width/2, ga_means, width, label='GA', color='lightblue')
        ax2.bar(x + width/2, de_means, width, label='DE', color='lightcoral')
        ax2.set_xlabel('QAP Instance')
        ax2.set_ylabel('Mean Best Cost')
        ax2.set_title('QAP Performance Comparison')
        ax2.set_xticks(x)
        ax2.set_xticklabels(qap_names)
        ax2.legend()
        ax2.grid(True, alpha=0.3)

    # Optimal Gap Comparison
    ax3 = axes[1, 0]
    all_names = tsp_names + qap_names
    ga_gaps = []
    de_gaps = []

    for name in all_names:
        stats_df = all_results[name]['statistics']
        ga_gap = float(stats_df[stats_df['Algorithm'] == 'GA']['Optimal Gap (%)'].iloc[0])
        de_gap = float(stats_df[stats_df['Algorithm'] == 'DE']['Optimal Gap (%)'].iloc[0])
        ga_gaps.append(ga_gap)
        de_gaps.append(de_gap)

    x = np.arange(len(all_names))
    width = 0.35
    ax3.bar(x - width/2, ga_gaps, width, label='GA', color='lightblue')
    ax3.bar(x + width/2, de_gaps, width, label='DE', color='lightcoral')
    ax3.set_xlabel('Problem Instance')
    ax3.set_ylabel('Optimality Gap (%)')
    ax3.set_title('Distance from Optimal Solution')
    ax3.set_xticks(x)
    ax3.set_xticklabels(all_names, rotation=45, ha='right')
    ax3.legend()
    ax3.grid(True, alpha=0.3)

    # Time Comparison
    ax4 = axes[1, 1]
    ga_times = []
    de_times = []

    for name in all_names:
        stats_df = all_results[name]['statistics']
        ga_time = float(stats_df[stats_df['Algorithm'] == 'GA']['Mean Time (s)'].iloc[0])
        de_time = float(stats_df[stats_df['Algorithm'] == 'DE']['Mean Time (s)'].iloc[0])
        ga_times.append(ga_time)
        de_times.append(de_time)

    x = np.arange(len(all_names))
    width = 0.35
    ax4.bar(x - width/2, ga_times, width, label='GA', color='lightblue')
    ax4.bar(x + width/2, de_times, width, label='DE', color='lightcoral')
    ax4.set_xlabel('Problem Instance')
    ax4.set_ylabel('Execution Time (s)')
    ax4.set_title('Computational Time Comparison')
    ax4.set_xticks(x)
    ax4.set_xticklabels(all_names, rotation=45, ha='right')
    ax4.legend()
    ax4.grid(True, alpha=0.3)

    plt.suptitle('CSC528 Project: Comprehensive Algorithm Comparison', fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
# @title Run Complete Experiments


# Run all experiments using the self-improving benchmark
print("Starting CSC528 Project Experiments with Self-Improving Benchmarks...")
print("This may take several minutes depending on your hardware.")

all_results = run_self_improving_benchmarks(tsp_instances, qap_instances)

# Generate final summary and visualizations
summary_df = create_final_summary(all_results)
plot_final_comparison(all_results)

print("\n" + "=" * 60)
print("ALL EXPERIMENTS COMPLETED!")
print("=" * 60)
# Out:
# Starting CSC528 Project Experiments with Self-Improving Benchmarks...
# This may take several minutes depending on your hardware.
# ============================================================
# RUNNING AUTO-TUNED TSP EXPERIMENTS
# ============================================================
# Loading cached GA parameters for eil51...
# Loading cached DE parameters for eil51...
#
# Optimal parameters identified for eil51!
#  > Tuned GA: MutRate=0.172, Elite=2
#  > Tuned DE: Strategy=best/1/bin, F=0.362
#
# ============================================================
# Running 30 experiments for eil51
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 440.33
#   Running DE... ✓ Best: 485.52
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 443.04
#   Running DE... ✓ Best: 528.01
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 453.03
#   Running DE... ✓ Best: 456.76
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 460.26
#   Running DE... ✓ Best: 481.70
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 453.15
#   Running DE... ✓ Best: 486.43
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 450.99
#   Running DE... ✓ Best: 471.45
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 452.52
#   Running DE... ✓ Best: 473.87
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 443.88
#   Running DE... ✓ Best: 461.34
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 451.15
#   Running DE... ✓ Best: 499.79
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 444.89
#   Running DE... ✓ Best: 457.34
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 442.45
#   Running DE... ✓ Best: 445.39
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 430.75
#   Running DE... ✓ Best: 472.04
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 449.42
#   Running DE... ✓ Best: 493.54
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 466.25
#   Running DE... ✓ Best: 503.39
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 455.85
#   Running DE... ✓ Best: 468.71
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 447.14
#   Running DE... ✓ Best: 455.62
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 450.10
#   Running DE... ✓ Best: 461.93
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 445.35
#   Running DE... ✓ Best: 442.40
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 446.74
#   Running DE... ✓ Best: 489.00
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 442.29
#   Running DE... ✓ Best: 478.86
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 445.56
#   Running DE... ✓ Best: 494.79
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 451.80
#   Running DE... ✓ Best: 447.15
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 454.46
#   Running DE... ✓ Best: 469.89
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 442.23
#   Running DE... ✓ Best: 530.47
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 450.36
#   Running DE... ✓ Best: 551.52
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 463.86
#   Running DE... ✓ Best: 480.05
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 441.32
#   Running DE... ✓ Best: 525.53
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 451.04
#   Running DE... ✓ Best: 496.94
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 450.53
#   Running DE... ✓ Best: 502.94
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 435.92
#   Running DE... ✓ Best: 492.83
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA    448.55    7.47    430.75     466.25         2.190     426           5.295
#        DE    483.51   26.18    442.40     551.52         4.012     426          13.499
#
# T-test: t=-6.913, p=0.0000
#
# eil51 completed:
#   GA - Best: 430.75,
#   Mean: 448.55
#   DE - Best: 442.40,
#   Mean: 483.51
# Tuning GA hyperparameters for berlin52...
# Tuning DE hyperparameters for berlin52...
#
# Optimal parameters identified for berlin52!
#  > Tuned GA: MutRate=0.104, Elite=7
#  > Tuned DE: Strategy=best/1/bin, F=0.362
#
# ============================================================
# Running 30 experiments for berlin52
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 8429.48
#   Running DE... ✓ Best: 8609.29
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 8466.35
#   Running DE... ✓ Best: 8243.39
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 8211.78
#   Running DE... ✓ Best: 9088.71
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 8312.06
#   Running DE... ✓ Best: 8239.12
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 8164.65
#   Running DE... ✓ Best: 8389.16
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 7995.39
#   Running DE... ✓ Best: 8350.79
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 8377.75
#   Running DE... ✓ Best: 8582.27
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 8054.13
#   Running DE... ✓ Best: 8950.27
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 8425.03
#   Running DE... ✓ Best: 8933.04
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 7981.74
#   Running DE... ✓ Best: 8502.05
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 8204.80
#   Running DE... ✓ Best: 8156.97
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 8189.98
#   Running DE... ✓ Best: 8469.33
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 8807.36
#   Running DE... ✓ Best: 8988.20
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 8485.86
#   Running DE... ✓ Best: 8582.27
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 8581.12
#   Running DE... ✓ Best: 8394.76
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 8278.49
#   Running DE... ✓ Best: 8362.04
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 8261.72
#   Running DE... ✓ Best: 7995.09
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 7619.15
#   Running DE... ✓ Best: 8378.73
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 8309.85
#   Running DE... ✓ Best: 9065.34
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 8211.96
#   Running DE... ✓ Best: 8756.26
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 8144.33
#   Running DE... ✓ Best: 8374.52
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 8736.27
#   Running DE... ✓ Best: 8295.82
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 8309.98
#   Running DE... ✓ Best: 8295.82
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 8095.72
#   Running DE... ✓ Best: 8099.67
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 7790.14
#   Running DE... ✓ Best: 8701.15
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 8000.26
#   Running DE... ✓ Best: 8294.21
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 8428.55
#   Running DE... ✓ Best: 9192.55
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 8481.09
#   Running DE... ✓ Best: 8347.97
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 8120.30
#   Running DE... ✓ Best: 8876.45
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 8342.49
#   Running DE... ✓ Best: 8182.19
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA   8260.59  248.69   7619.15    8807.36         1.336    7542           9.528
#        DE   8523.25  318.55   7995.09    9192.55         3.902    7542          13.010
#
# T-test: t=-3.500, p=0.0009
#
# berlin52 completed:
#   GA - Best: 7619.15,
#   Mean: 8260.59
#   DE - Best: 7995.09,
#   Mean: 8523.25
# Tuning GA hyperparameters for st70...
# Tuning DE hyperparameters for st70...
#
# Optimal parameters identified for st70!
#  > Tuned GA: MutRate=0.046, Elite=9
#  > Tuned DE: Strategy=best/1/bin, F=0.511
#
# ============================================================
# Running 30 experiments for st70
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 720.32
#   Running DE... ✓ Best: 724.45
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 715.75
#   Running DE... ✓ Best: 765.27
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 705.00
#   Running DE... ✓ Best: 724.58
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 751.47
#   Running DE... ✓ Best: 750.08
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 751.29
#   Running DE... ✓ Best: 757.90
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 720.85
#   Running DE... ✓ Best: 755.55
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 711.34
#   Running DE... ✓ Best: 826.60
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 742.31
#   Running DE... ✓ Best: 722.61
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 733.21
#   Running DE... ✓ Best: 761.07
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 713.89
#   Running DE... ✓ Best: 724.60
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 771.99
#   Running DE... ✓ Best: 720.22
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 706.74
#   Running DE... ✓ Best: 779.78
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 722.86
#   Running DE... ✓ Best: 719.60
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 753.19
#   Running DE... ✓ Best: 754.85
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 721.34
#   Running DE... ✓ Best: 726.48
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 721.25
#   Running DE... ✓ Best: 782.74
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 727.23
#   Running DE... ✓ Best: 775.35
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 716.52
#   Running DE... ✓ Best: 761.42
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 705.30
#   Running DE... ✓ Best: 765.27
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 722.90
#   Running DE... ✓ Best: 754.85
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 763.01
#   Running DE... ✓ Best: 742.49
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 706.67
#   Running DE... ✓ Best: 751.74
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 704.46
#   Running DE... ✓ Best: 738.31
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 729.63
#   Running DE... ✓ Best: 713.23
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 712.64
#   Running DE... ✓ Best: 726.48
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 742.90
#   Running DE... ✓ Best: 788.46
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 709.44
#   Running DE... ✓ Best: 808.20
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 731.37
#   Running DE... ✓ Best: 802.93
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 723.19
#   Running DE... ✓ Best: 709.26
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 707.01
#   Running DE... ✓ Best: 784.53
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA    725.50   18.01    704.46     771.99         3.222     675           7.482
#        DE    753.96   29.74    709.26     826.60         5.360     675          11.698
#
# T-test: t=-4.408, p=0.0000
#
# st70 completed:
#   GA - Best: 704.46,
#   Mean: 725.50
#   DE - Best: 709.26,
#   Mean: 753.96
# Tuning GA hyperparameters for pr76...
# Tuning DE hyperparameters for pr76...
#
# Optimal parameters identified for pr76!
#  > Tuned GA: MutRate=0.225, Elite=3
#  > Tuned DE: Strategy=best/1/bin, F=0.304
#
# ============================================================
# Running 30 experiments for pr76
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 118231.22
#   Running DE... ✓ Best: 119524.06
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 109689.61
#   Running DE... ✓ Best: 122431.72
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 116149.94
#   Running DE... ✓ Best: 119812.47
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 112165.31
#   Running DE... ✓ Best: 126797.74
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 112876.79
#   Running DE... ✓ Best: 131491.22
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 114244.09
#   Running DE... ✓ Best: 123503.20
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 117059.38
#   Running DE... ✓ Best: 120148.74
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 112586.80
#   Running DE... ✓ Best: 125666.04
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 119550.18
#   Running DE... ✓ Best: 124934.08
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 112044.84
#   Running DE... ✓ Best: 123068.67
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 112030.65
#   Running DE... ✓ Best: 135690.07
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 115520.78
#   Running DE... ✓ Best: 116395.21
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 116715.16
#   Running DE... ✓ Best: 123068.67
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 116038.88
#   Running DE... ✓ Best: 122601.72
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 111294.65
#   Running DE... ✓ Best: 121594.79
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 113684.76
#   Running DE... ✓ Best: 117362.04
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 112924.41
#   Running DE... ✓ Best: 130540.82
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 112226.81
#   Running DE... ✓ Best: 125830.00
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 118377.08
#   Running DE... ✓ Best: 130488.74
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 114149.72
#   Running DE... ✓ Best: 123769.84
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 115403.51
#   Running DE... ✓ Best: 116671.30
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 112657.89
#   Running DE... ✓ Best: 129905.93
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 118027.05
#   Running DE... ✓ Best: 131747.22
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 117231.67
#   Running DE... ✓ Best: 115993.11
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 112219.83
#   Running DE... ✓ Best: 147720.18
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 113601.84
#   Running DE... ✓ Best: 127160.68
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 116176.43
#   Running DE... ✓ Best: 120407.38
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 110274.52
#   Running DE... ✓ Best: 118194.92
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 116075.25
#   Running DE... ✓ Best: 120708.79
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 114266.25
#   Running DE... ✓ Best: 135690.07
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA 114449.84 2523.75 109689.61  119550.18         2.348  108159           5.816
#        DE 124963.98 6857.09 115993.11  147720.18         3.492  108159          15.537
#
# T-test: t=-7.749, p=0.0000
#
# pr76 completed:
#   GA - Best: 109689.61,
#   Mean: 114449.84
#   DE - Best: 115993.11,
#   Mean: 124963.98
# Tuning GA hyperparameters for eil101...
# Tuning DE hyperparameters for eil101...
#
# Optimal parameters identified for eil101!
#  > Tuned GA: MutRate=0.054, Elite=4
#  > Tuned DE: Strategy=best/1/bin, F=0.481
#
# ============================================================
# Running 30 experiments for eil101
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 672.93
#   Running DE... ✓ Best: 687.00
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 682.79
#   Running DE... ✓ Best: 711.26
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 700.52
#   Running DE... ✓ Best: 692.70
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 679.49
#   Running DE... ✓ Best: 682.73
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 691.84
#   Running DE... ✓ Best: 744.34
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 684.89
#   Running DE... ✓ Best: 704.67
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 690.67
#   Running DE... ✓ Best: 737.84
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 702.94
#   Running DE... ✓ Best: 689.30
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 700.31
#   Running DE... ✓ Best: 692.90
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 684.86
#   Running DE... ✓ Best: 748.88
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 691.33
#   Running DE... ✓ Best: 702.76
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 692.96
#   Running DE... ✓ Best: 707.42
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 673.88
#   Running DE... ✓ Best: 709.88
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 700.36
#   Running DE... ✓ Best: 709.60
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 694.19
#   Running DE... ✓ Best: 774.64
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 688.44
#   Running DE... ✓ Best: 697.21
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 708.27
#   Running DE... ✓ Best: 683.98
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 701.14
#   Running DE... ✓ Best: 700.73
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 703.34
#   Running DE... ✓ Best: 718.79
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 676.21
#   Running DE... ✓ Best: 725.08
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 674.01
#   Running DE... ✓ Best: 757.38
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 691.54
#   Running DE... ✓ Best: 708.96
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 701.98
#   Running DE... ✓ Best: 693.45
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 689.57
#   Running DE... ✓ Best: 917.74
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 689.73
#   Running DE... ✓ Best: 816.23
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 681.85
#   Running DE... ✓ Best: 689.42
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 698.47
#   Running DE... ✓ Best: 776.52
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 705.72
#   Running DE... ✓ Best: 690.23
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 701.37
#   Running DE... ✓ Best: 779.67
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 706.60
#   Running DE... ✓ Best: 702.92
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA    692.07   10.30    672.93     708.27         4.168     629          10.028
#        DE    725.14   48.81    682.73     917.74         2.649     629          15.285
#
# T-test: t=-3.569, p=0.0007
#
# eil101 completed:
#   GA - Best: 672.93,
#   Mean: 692.07
#   DE - Best: 682.73,
#   Mean: 725.14
# Tuning GA hyperparameters for ch130...
# Tuning DE hyperparameters for ch130...
#
# Optimal parameters identified for ch130!
#  > Tuned GA: MutRate=0.131, Elite=3
#  > Tuned DE: Strategy=best/1/bin, F=0.721
#
# ============================================================
# Running 30 experiments for ch130
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 6683.05
#   Running DE... ✓ Best: 6897.02
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 6760.17
#   Running DE... ✓ Best: 6793.31
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 6560.29
#   Running DE... ✓ Best: 6958.55
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 6668.98
#   Running DE... ✓ Best: 6479.11
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 6581.12
#   Running DE... ✓ Best: 6599.12
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 6743.22
#   Running DE... ✓ Best: 7052.08
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 6590.24
#   Running DE... ✓ Best: 6773.79
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 6780.94
#   Running DE... ✓ Best: 6707.13
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 6665.98
#   Running DE... ✓ Best: 7019.78
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 6691.24
#   Running DE... ✓ Best: 6725.01
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 6999.60
#   Running DE... ✓ Best: 6798.58
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 6477.11
#   Running DE... ✓ Best: 7286.70
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 6514.64
#   Running DE... ✓ Best: 7286.90
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 6950.05
#   Running DE... ✓ Best: 6774.26
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 7167.03
#   Running DE... ✓ Best: 7296.81
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 6667.61
#   Running DE... ✓ Best: 6854.77
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 6590.58
#   Running DE... ✓ Best: 6664.99
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 6767.15
#   Running DE... ✓ Best: 7230.58
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 6673.88
#   Running DE... ✓ Best: 7094.80
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 6688.37
#   Running DE... ✓ Best: 6800.22
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 6605.88
#   Running DE... ✓ Best: 7286.23
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 6688.96
#   Running DE... ✓ Best: 6630.86
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 6637.61
#   Running DE... ✓ Best: 6914.95
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 6750.22
#   Running DE... ✓ Best: 7286.23
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 6573.02
#   Running DE... ✓ Best: 7373.00
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 6617.60
#   Running DE... ✓ Best: 6883.96
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 6888.49
#   Running DE... ✓ Best: 7454.63
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 6520.16
#   Running DE... ✓ Best: 7219.45
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 6467.84
#   Running DE... ✓ Best: 7005.46
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 6554.19
#   Running DE... ✓ Best: 6925.70
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA   6684.17  153.50   6467.84    7167.03         2.132    6110           9.397
#        DE   6969.13  256.52   6479.11    7454.63         2.042    6110          14.061
#
# T-test: t=-5.133, p=0.0000
#
# ch130 completed:
#   GA - Best: 6467.84,
#   Mean: 6684.17
#   DE - Best: 6479.11,
#   Mean: 6969.13
# Tuning GA hyperparameters for tsp225...
# Tuning DE hyperparameters for tsp225...
#
# Optimal parameters identified for tsp225!
#  > Tuned GA: MutRate=0.143, Elite=8
#  > Tuned DE: Strategy=best/1/bin, F=0.537
#
# ============================================================
# Running 30 experiments for tsp225
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 4318.29
#   Running DE... ✓ Best: 4335.23
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 4274.12
#   Running DE... ✓ Best: 4322.42
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 4412.07
#   Running DE... ✓ Best: 4181.87
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 4249.61
#   Running DE... ✓ Best: 4517.35
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 4359.02
#   Running DE... ✓ Best: 4198.20
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 4352.86
#   Running DE... ✓ Best: 4253.01
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 4126.04
#   Running DE... ✓ Best: 4236.29
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 4394.25
#   Running DE... ✓ Best: 4216.40
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 4255.52
#   Running DE... ✓ Best: 4356.06
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 4217.28
#   Running DE... ✓ Best: 4229.80
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 4369.07
#   Running DE... ✓ Best: 4331.58
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 4414.31
#   Running DE... ✓ Best: 4280.98
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 4181.40
#   Running DE... ✓ Best: 4288.80
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 4323.07
#   Running DE... ✓ Best: 4148.69
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 4227.51
#   Running DE... ✓ Best: 4349.47
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 4331.20
#   Running DE... ✓ Best: 4337.31
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 4267.19
#   Running DE... ✓ Best: 4220.10
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 4167.04
#   Running DE... ✓ Best: 4260.39
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 4300.31
#   Running DE... ✓ Best: 4188.85
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 4325.65
#   Running DE... ✓ Best: 4148.19
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 4266.85
#   Running DE... ✓ Best: 4348.86
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 4221.37
#   Running DE... ✓ Best: 4314.43
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 4311.72
#   Running DE... ✓ Best: 4357.98
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 4262.09
#   Running DE... ✓ Best: 4223.02
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 4312.23
#   Running DE... ✓ Best: 4392.90
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 4412.36
#   Running DE... ✓ Best: 4323.64
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 4218.97
#   Running DE... ✓ Best: 4359.21
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 4228.60
#   Running DE... ✓ Best: 4262.41
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 4431.84
#   Running DE... ✓ Best: 4354.81
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 4252.31
#   Running DE... ✓ Best: 4370.15
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA   4292.80   77.42   4126.04    4431.84         3.944    3916           9.622
#        DE   4290.28   81.09   4148.19    4517.35         8.162    3916           9.558
#
# T-test: t=0.121, p=0.9039
#
# tsp225 completed:
#   GA - Best: 4126.04,
#   Mean: 4292.80
#   DE - Best: 4148.19,
#   Mean: 4290.28
# Tuning GA hyperparameters for a280...
# Tuning DE hyperparameters for a280...
#
# Optimal parameters identified for a280!
#  > Tuned GA: MutRate=0.031, Elite=2
#  > Tuned DE: Strategy=best/1/bin, F=0.427
#
# ============================================================
# Running 30 experiments for a280
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 2956.38
#   Running DE... ✓ Best: 2994.69
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 3052.34
#   Running DE... ✓ Best: 3142.16
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 3018.38
#   Running DE... ✓ Best: 2991.56
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 2941.31
#   Running DE... ✓ Best: 3487.43
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 3182.26
#   Running DE... ✓ Best: 3012.88
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 2895.18
#   Running DE... ✓ Best: 2949.05
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 3042.23
#   Running DE... ✓ Best: 2989.28
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 2953.36
#   Running DE... ✓ Best: 2787.25
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 3069.94
#   Running DE... ✓ Best: 2921.86
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 2984.22
#   Running DE... ✓ Best: 2883.01
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 2898.84
#   Running DE... ✓ Best: 3039.50
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 2977.43
#   Running DE... ✓ Best: 2828.31
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 2947.06
#   Running DE... ✓ Best: 2924.33
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 2891.82
#   Running DE... ✓ Best: 3080.24
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 3266.77
#   Running DE... ✓ Best: 3097.18
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 2921.26
#   Running DE... ✓ Best: 2941.35
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 2983.36
#   Running DE... ✓ Best: 2988.29
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 3073.15
#   Running DE... ✓ Best: 2939.42
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 2925.55
#   Running DE... ✓ Best: 3147.81
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 2988.88
#   Running DE... ✓ Best: 2935.24
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 2971.27
#   Running DE... ✓ Best: 2905.31
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 2850.72
#   Running DE... ✓ Best: 2977.22
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 3020.62
#   Running DE... ✓ Best: 2865.21
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 2853.11
#   Running DE... ✓ Best: 2930.75
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 3055.62
#   Running DE... ✓ Best: 2940.59
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 2956.63
#   Running DE... ✓ Best: 3012.62
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 3009.73
#   Running DE... ✓ Best: 2954.85
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 3016.12
#   Running DE... ✓ Best: 2857.60
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 2912.62
#   Running DE... ✓ Best: 3099.23
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 2943.37
#   Running DE... ✓ Best: 2940.61
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA   2985.32   87.65   2850.72    3266.77         6.409    2579          15.755
#        DE   2985.49  126.13   2787.25    3487.43         8.649    2579          15.762
#
# T-test: t=-0.006, p=0.9951
#
# a280 completed:
#   GA - Best: 2850.72,
#   Mean: 2985.32
#   DE - Best: 2787.25,
#   Mean: 2985.49
# Tuning GA hyperparameters for lin318...
# Tuning DE hyperparameters for lin318...
#
# Optimal parameters identified for lin318!
#  > Tuned GA: MutRate=0.178, Elite=5
#  > Tuned DE: Strategy=best/1/bin, F=0.596
#
# ============================================================
# Running 30 experiments for lin318
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 47921.07
#   Running DE... ✓ Best: 48190.88
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 45790.65
#   Running DE... ✓ Best: 45818.55
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 44853.16
#   Running DE... ✓ Best: 46138.32
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 46728.84
#   Running DE... ✓ Best: 47275.67
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 46506.26
#   Running DE... ✓ Best: 46637.63
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 46169.35
#   Running DE... ✓ Best: 46872.82
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 46071.31
#   Running DE... ✓ Best: 48237.70
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 47826.50
#   Running DE... ✓ Best: 48159.43
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 46161.82
#   Running DE... ✓ Best: 49457.25
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 47262.42
#   Running DE... ✓ Best: 48369.24
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 47512.30
#   Running DE... ✓ Best: 49253.96
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 46770.94
#   Running DE... ✓ Best: 46543.54
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 45896.31
#   Running DE... ✓ Best: 46895.43
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 45768.13
#   Running DE... ✓ Best: 49689.72
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 45452.27
#   Running DE... ✓ Best: 47285.91
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 45729.22
#   Running DE... ✓ Best: 44306.98
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 45981.02
#   Running DE... ✓ Best: 46221.76
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 46839.92
#   Running DE... ✓ Best: 49949.48
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 47230.26
#   Running DE... ✓ Best: 47434.20
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 44571.60
#   Running DE... ✓ Best: 47325.07
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 45272.67
#   Running DE... ✓ Best: 46053.49
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 47841.32
#   Running DE... ✓ Best: 45795.96
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 45206.26
#   Running DE... ✓ Best: 46198.63
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 47241.35
#   Running DE... ✓ Best: 48953.27
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 45504.43
#   Running DE... ✓ Best: 48708.25
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 47923.76
#   Running DE... ✓ Best: 49303.86
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 47279.63
#   Running DE... ✓ Best: 47972.50
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 46371.71
#   Running DE... ✓ Best: 47474.23
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 47811.78
#   Running DE... ✓ Best: 46670.64
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 47228.15
#   Running DE... ✓ Best: 48049.87
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA  46490.81  962.33  44571.60   47923.76         9.940   42029          10.616
#        DE  47508.14 1337.92  44306.98   49949.48        11.453   42029          13.037
#
# T-test: t=-3.324, p=0.0015
#
# lin318 completed:
#   GA - Best: 44571.60,
#   Mean: 46490.81
#   DE - Best: 44306.98,
#   Mean: 47508.14
# Tuning GA hyperparameters for pcb442...
# Tuning DE hyperparameters for pcb442...
#
# Optimal parameters identified for pcb442!
#  > Tuned GA: MutRate=0.200, Elite=9
#  > Tuned DE: Strategy=best/1/bin, F=0.721
#
# ============================================================
# Running 30 experiments for pcb442
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 56970.49
#   Running DE... ✓ Best: 57793.84
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 56880.90
#   Running DE... ✓ Best: 55252.07
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 56356.99
#   Running DE... ✓ Best: 56103.84
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 57923.49
#   Running DE... ✓ Best: 54647.08
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 58283.79
#   Running DE... ✓ Best: 56167.70
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 60677.71
#   Running DE... ✓ Best: 57940.31
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 56600.50
#   Running DE... ✓ Best: 54038.06
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 55843.85
#   Running DE... ✓ Best: 55354.28
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 56120.42
#   Running DE... ✓ Best: 58398.17
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 57856.05
#   Running DE... ✓ Best: 57944.78
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 57888.40
#   Running DE... ✓ Best: 56790.74
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 55942.02
#   Running DE... ✓ Best: 57433.27
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 55848.94
#   Running DE... ✓ Best: 55611.12
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 59665.09
#   Running DE... ✓ Best: 56879.55
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 56651.28
#   Running DE... ✓ Best: 56780.62
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 56293.64
#   Running DE... ✓ Best: 56423.32
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 57569.40
#   Running DE... ✓ Best: 57916.55
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 57144.98
#   Running DE... ✓ Best: 56246.65
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 57930.53
#   Running DE... ✓ Best: 59017.16
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 57708.65
#   Running DE... ✓ Best: 58386.16
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 57299.09
#   Running DE... ✓ Best: 57601.30
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 58497.09
#   Running DE... ✓ Best: 57618.42
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 58305.49
#   Running DE... ✓ Best: 57451.00
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 56755.37
#   Running DE... ✓ Best: 55251.90
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 55897.43
#   Running DE... ✓ Best: 58325.00
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 56900.55
#   Running DE... ✓ Best: 54134.04
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 56819.62
#   Running DE... ✓ Best: 55894.03
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 56319.56
#   Running DE... ✓ Best: 57628.49
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 58213.80
#   Running DE... ✓ Best: 56265.21
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 56698.33
#   Running DE... ✓ Best: 56985.67
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA  57262.11 1117.24  55843.85   60677.71         5.081   50778          12.770
#        DE  56742.68 1291.37  54038.06   59017.16         6.320   50778          11.747
#
# T-test: t=1.638, p=0.1068
#
# pcb442 completed:
#   GA - Best: 55843.85,
#   Mean: 57262.11
#   DE - Best: 54038.06,
#   Mean: 56742.68
# Tuning GA hyperparameters for att532...
# Tuning DE hyperparameters for att532...
#
# Optimal parameters identified for att532!
#  > Tuned GA: MutRate=0.158, Elite=5
#  > Tuned DE: Strategy=best/1/bin, F=0.399
#
# ============================================================
# Running 30 experiments for att532
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 94537.42
#   Running DE... ✓ Best: 96335.68
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 93762.68
#   Running DE... ✓ Best: 99572.61
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 95609.60
#   Running DE... ✓ Best: 95985.95
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 99049.29
#   Running DE... ✓ Best: 97876.06
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 92600.77
#   Running DE... ✓ Best: 97832.51
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 96206.19
#   Running DE... ✓ Best: 99193.19
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 98436.95
#   Running DE... ✓ Best: 94849.93
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 98237.42
#   Running DE... ✓ Best: 95104.49
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 100798.31
#   Running DE... ✓ Best: 97221.41
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 96646.01
#   Running DE... ✓ Best: 100134.97
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 97582.52
#   Running DE... ✓ Best: 96650.28
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 96326.48
#   Running DE... ✓ Best: 94059.76
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 99144.44
#   Running DE... ✓ Best: 95524.55
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 98636.39
#   Running DE... ✓ Best: 97411.26
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 98097.17
#   Running DE... ✓ Best: 95523.17
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 94353.50
#   Running DE... ✓ Best: 94217.74
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 96451.44
#   Running DE... ✓ Best: 95144.38
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 94973.94
#   Running DE... ✓ Best: 94866.35
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 95657.78
#   Running DE... ✓ Best: 94871.42
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 96981.73
#   Running DE... ✓ Best: 97340.06
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 96190.16
#   Running DE... ✓ Best: 96252.12
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 98001.44
#   Running DE... ✓ Best: 95515.70
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 97436.01
#   Running DE... ✓ Best: 96035.26
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 95923.08
#   Running DE... ✓ Best: 95096.29
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 96599.52
#   Running DE... ✓ Best: 96915.27
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 96742.94
#   Running DE... ✓ Best: 94660.46
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 96148.26
#   Running DE... ✓ Best: 93904.23
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 96453.36
#   Running DE... ✓ Best: 98794.54
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 97341.54
#   Running DE... ✓ Best: 96497.31
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 95715.16
#   Running DE... ✓ Best: 95884.89
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA  96688.05 1697.07  92600.77  100798.31         5.455   27686         249.231
#        DE  96309.06 1621.78  93904.23  100134.97        12.529   27686         247.862
#
# T-test: t=0.869, p=0.3882
#
# att532 completed:
#   GA - Best: 92600.77,
#   Mean: 96688.05
#   DE - Best: 93904.23,
#   Mean: 96309.06
# Tuning GA hyperparameters for rat575...
# Tuning DE hyperparameters for rat575...
#
# Optimal parameters identified for rat575!
#  > Tuned GA: MutRate=0.157, Elite=4
#  > Tuned DE: Strategy=best/1/bin, F=0.481
#
# ============================================================
# Running 30 experiments for rat575
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 7598.37
#   Running DE... ✓ Best: 7378.99
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 7726.68
#   Running DE... ✓ Best: 7335.68
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 7573.26
#   Running DE... ✓ Best: 7393.27
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 7669.87
#   Running DE... ✓ Best: 7727.10
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 7744.15
#   Running DE... ✓ Best: 8402.27
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 7576.54
#   Running DE... ✓ Best: 8207.23
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 7627.82
#   Running DE... ✓ Best: 7446.93
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 7570.75
#   Running DE... ✓ Best: 8422.37
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 7624.39
#   Running DE... ✓ Best: 7432.21
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 7690.24
#   Running DE... ✓ Best: 7359.65
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 7592.73
#   Running DE... ✓ Best: 7699.34
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 7647.12
#   Running DE... ✓ Best: 7547.38
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 7673.60
#   Running DE... ✓ Best: 7382.63
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 7709.22
#   Running DE... ✓ Best: 8151.87
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 7706.94
#   Running DE... ✓ Best: 8335.47
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 7557.05
#   Running DE... ✓ Best: 7416.37
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 7671.63
#   Running DE... ✓ Best: 7271.24
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 7783.90
#   Running DE... ✓ Best: 8169.89
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 7540.84
#   Running DE... ✓ Best: 7295.50
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 7647.36
#   Running DE... ✓ Best: 7443.14
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 7678.46
#   Running DE... ✓ Best: 7651.97
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 7604.29
#   Running DE... ✓ Best: 7551.44
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 7595.07
#   Running DE... ✓ Best: 7342.70
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 7607.79
#   Running DE... ✓ Best: 7381.90
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 7852.46
#   Running DE... ✓ Best: 8345.05
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 7743.00
#   Running DE... ✓ Best: 8118.40
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 7561.08
#   Running DE... ✓ Best: 7529.27
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 7513.59
#   Running DE... ✓ Best: 7481.89
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 7651.82
#   Running DE... ✓ Best: 7495.95
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 7507.22
#   Running DE... ✓ Best: 7464.71
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA   7641.57   79.54   7507.22    7852.46         9.718    6773          12.824
#        DE   7672.73  378.46   7271.24    8422.37         7.876    6773          13.284
#
# T-test: t=-0.434, p=0.6661
#
# rat575 completed:
#   GA - Best: 7507.22,
#   Mean: 7641.57
#   DE - Best: 7271.24,
#   Mean: 7672.73
# Tuning GA hyperparameters for rat783...
# Tuning DE hyperparameters for rat783...
#
# Optimal parameters identified for rat783!
#  > Tuned GA: MutRate=0.224, Elite=6
#  > Tuned DE: Strategy=best/1/bin, F=0.721
#
# ============================================================
# Running 30 experiments for rat783
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 9881.50
#   Running DE... ✓ Best: 9822.39
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 10272.72
#   Running DE... ✓ Best: 9690.24
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 10002.21
#   Running DE... ✓ Best: 9954.08
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 9944.32
#   Running DE... ✓ Best: 9928.25
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 10040.81
#   Running DE... ✓ Best: 9804.68
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 10324.01
#   Running DE... ✓ Best: 9646.96
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 9793.53
#   Running DE... ✓ Best: 9638.33
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 9836.09
#   Running DE... ✓ Best: 9655.58
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 9886.23
#   Running DE... ✓ Best: 9812.00
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 9772.45
#   Running DE... ✓ Best: 9882.61
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 9999.43
#   Running DE... ✓ Best: 9607.17
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 9973.92
#   Running DE... ✓ Best: 9877.55
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 9924.31
#   Running DE... ✓ Best: 9868.11
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 9995.66
#   Running DE... ✓ Best: 9876.91
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 10105.27
#   Running DE... ✓ Best: 9831.29
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 9853.11
#   Running DE... ✓ Best: 9899.52
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 10045.48
#   Running DE... ✓ Best: 9942.56
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 10056.34
#   Running DE... ✓ Best: 9924.77
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 10023.52
#   Running DE... ✓ Best: 9968.25
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 10000.75
#   Running DE... ✓ Best: 9750.46
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 9937.49
#   Running DE... ✓ Best: 9738.84
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 9993.58
#   Running DE... ✓ Best: 9642.79
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 10033.01
#   Running DE... ✓ Best: 9854.67
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 9929.25
#   Running DE... ✓ Best: 9683.68
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 9866.42
#   Running DE... ✓ Best: 9696.67
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 9885.62
#   Running DE... ✓ Best: 9868.39
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 9843.62
#   Running DE... ✓ Best: 10224.86
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 9964.08
#   Running DE... ✓ Best: 10090.89
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 9961.38
#   Running DE... ✓ Best: 9952.48
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 9889.20
#   Running DE... ✓ Best: 9903.08
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA   9967.84  119.27   9772.45   10324.01        13.974    8806          13.194
#        DE   9834.60  139.62   9607.17   10224.86        11.496    8806          11.681
#
# T-test: t=3.908, p=0.0002
#
# rat783 completed:
#   GA - Best: 9772.45,
#   Mean: 9967.84
#   DE - Best: 9607.17,
#   Mean: 9834.60
# Tuning GA hyperparameters for pr1002...
# Tuning DE hyperparameters for pr1002...
#
# Optimal parameters identified for pr1002!
#  > Tuned GA: MutRate=0.243, Elite=7
#  > Tuned DE: Strategy=best/1/bin, F=0.427
#
# ============================================================
# Running 30 experiments for pr1002
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 293154.69
#   Running DE... ✓ Best: 296786.80
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 294689.08
#   Running DE... ✓ Best: 282704.68
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 292316.96
#   Running DE... ✓ Best: 294975.88
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 292980.00
#   Running DE... ✓ Best: 297897.69
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 295838.11
#   Running DE... ✓ Best: 288289.85
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 289823.00
#   Running DE... ✓ Best: 282481.63
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 290572.82
#   Running DE... ✓ Best: 286560.24
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 292164.86
#   Running DE... ✓ Best: 285205.36
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 294140.91
#   Running DE... ✓ Best: 294267.79
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 294334.26
#   Running DE... ✓ Best: 295343.36
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 294573.27
#   Running DE... ✓ Best: 292760.72
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 294495.51
#   Running DE... ✓ Best: 297290.80
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 293310.23
#   Running DE... ✓ Best: 297736.03
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 291379.34
#   Running DE... ✓ Best: 291718.90
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 296669.75
#   Running DE... ✓ Best: 278721.94
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 295138.10
#   Running DE... ✓ Best: 293039.58
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 294407.60
#   Running DE... ✓ Best: 292835.63
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 289289.67
#   Running DE... ✓ Best: 285696.05
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 292074.02
#   Running DE... ✓ Best: 289687.15
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 294922.91
#   Running DE... ✓ Best: 297780.07
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 292549.98
#   Running DE... ✓ Best: 281029.64
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 295844.94
#   Running DE... ✓ Best: 291890.04
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 289931.37
#   Running DE... ✓ Best: 287940.72
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 290197.83
#   Running DE... ✓ Best: 280718.47
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 285664.34
#   Running DE... ✓ Best: 288574.77
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 289865.60
#   Running DE... ✓ Best: 279498.60
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 284728.57
#   Running DE... ✓ Best: 279523.23
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 293884.29
#   Running DE... ✓ Best: 295852.09
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 293994.82
#   Running DE... ✓ Best: 288162.14
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 287976.86
#   Running DE... ✓ Best: 299888.42
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA 292363.79 2883.38 284728.57  296669.75        30.939  259045          12.862
#        DE 289828.61 6339.51 278721.94  299888.42        32.459  259045          11.883
#
# T-test: t=1.960, p=0.0548
#
# pr1002 completed:
#   GA - Best: 284728.57,
#   Mean: 292363.79
#   DE - Best: 278721.94,
#   Mean: 289828.61
# Tuning GA hyperparameters for u1060...
# Tuning DE hyperparameters for u1060...
#
# Optimal parameters identified for u1060!
#  > Tuned GA: MutRate=0.087, Elite=3
#  > Tuned DE: Strategy=best/1/bin, F=0.597
#
# ============================================================
# Running 30 experiments for u1060
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 286214.02
#   Running DE... ✓ Best: 255545.26
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 256898.52
#   Running DE... ✓ Best: 249324.36
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 251761.10
#   Running DE... ✓ Best: 261863.20
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 249455.72
#   Running DE... ✓ Best: 261901.08
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 252350.14
#   Running DE... ✓ Best: 251428.72
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 252055.81
#   Running DE... ✓ Best: 262063.13
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 258727.12
#   Running DE... ✓ Best: 250976.93
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 247957.68
#   Running DE... ✓ Best: 250753.36
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 253242.28
#   Running DE... ✓ Best: 264052.16
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 259185.36
#   Running DE... ✓ Best: 249540.78
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 250267.84
#   Running DE... ✓ Best: 252719.20
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 256709.51
#   Running DE... ✓ Best: 249729.60
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 250543.77
#   Running DE... ✓ Best: 262648.76
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 255135.88
#   Running DE... ✓ Best: 250314.82
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 254774.59
#   Running DE... ✓ Best: 250879.61
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 249007.82
#   Running DE... ✓ Best: 253100.53
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 252026.35
#   Running DE... ✓ Best: 267943.73
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 250069.16
#   Running DE... ✓ Best: 255466.87
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 258556.22
#   Running DE... ✓ Best: 251106.03
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 252928.83
#   Running DE... ✓ Best: 249965.60
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 254876.25
#   Running DE... ✓ Best: 260406.78
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 249756.59
#   Running DE... ✓ Best: 251506.80
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 257919.95
#   Running DE... ✓ Best: 249095.15
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 250364.83
#   Running DE... ✓ Best: 262282.71
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 248851.61
#   Running DE... ✓ Best: 255845.07
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 258052.94
#   Running DE... ✓ Best: 247537.03
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 251430.58
#   Running DE... ✓ Best: 249362.30
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 249810.97
#   Running DE... ✓ Best: 252585.85
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 255049.75
#   Running DE... ✓ Best: 244873.20
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 267460.28
#   Running DE... ✓ Best: 248992.63
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA 254714.72 7181.69 247957.68  286214.02        30.187  224094          13.664
#        DE 254127.04 5823.15 244873.20  267943.73        37.326  224094          13.402
#
# T-test: t=0.342, p=0.7334
#
# u1060 completed:
#   GA - Best: 247957.68,
#   Mean: 254714.72
#   DE - Best: 244873.20,
#   Mean: 254127.04
# Tuning GA hyperparameters for vm1084...
# Tuning DE hyperparameters for vm1084...
#
# Optimal parameters identified for vm1084!
#  > Tuned GA: MutRate=0.159, Elite=5
#  > Tuned DE: Strategy=best/1/bin, F=0.406
#
# ============================================================
# Running 30 experiments for vm1084
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 269068.26
#   Running DE... ✓ Best: 268542.92
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 274937.37
#   Running DE... ✓ Best: 303941.07
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 278119.86
#   Running DE... ✓ Best: 270981.65
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 273773.68
#   Running DE... ✓ Best: 266711.88
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 267969.43
#   Running DE... ✓ Best: 264206.43
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 267301.98
#   Running DE... ✓ Best: 263575.50
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 284440.49
#   Running DE... ✓ Best: 265218.08
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 269943.60
#   Running DE... ✓ Best: 269059.69
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 278825.31
#   Running DE... ✓ Best: 264549.85
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 270345.01
#   Running DE... ✓ Best: 271077.97
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 276672.08
#   Running DE... ✓ Best: 266564.62
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 267252.16
#   Running DE... ✓ Best: 268349.09
#
# ▶ Run 13/30
# ...
#   Running DE... ✓ Best: 9916.00
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 10506.00
#   Running DE... ✓ Best: 10240.00
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 13412.00
#   Running DE... ✓ Best: 9916.00
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 10906.00
#   Running DE... ✓ Best: 10214.00
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 11458.00
#   Running DE... ✓ Best: 10096.00
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 11838.00
#   Running DE... ✓ Best: 10096.00
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 12444.00
#   Running DE... ✓ Best: 9916.00
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 11838.00
#   Running DE... ✓ Best: 10096.00
#
# Statistical Summary:
# Algorithm Mean Cost Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA  11490.60 1113.20   9552.00   14954.00         8.131    9552          20.295
#        DE  10406.27  542.86   9916.00   11838.00         8.233    9552           8.943
#
# T-test: t=4.715, p=0.0000
#
# chr12a completed:
#   GA - Best: 9552.00,
#   Mean: 11490.60
#   DE - Best: 9916.00,
#   Mean: 10406.27
# Tuning GA hyperparameters for tai20a...
# Tuning DE hyperparameters for tai20a...
#
# Optimal parameters identified for tai20a!
#  > Tuned GA: MutRate=0.144, Elite=5
#  > Tuned DE: Strategy=best/1/bin, F=0.941
#
# ============================================================
# Running 30 experiments for tai20a
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 763154.00
#   Running DE... ✓ Best: 768506.00
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 716130.00
#   Running DE... ✓ Best: 769638.00
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 744558.00
#   Running DE... ✓ Best: 763178.00
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 736192.00
#   Running DE... ✓ Best: 784586.00
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 749246.00
#   Running DE... ✓ Best: 757694.00
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 735842.00
#   Running DE... ✓ Best: 766820.00
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 752124.00
#   Running DE... ✓ Best: 777884.00
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 727406.00
#   Running DE... ✓ Best: 765240.00
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 739112.00
#   Running DE... ✓ Best: 767554.00
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 753112.00
#   Running DE... ✓ Best: 782578.00
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 740736.00
#   Running DE... ✓ Best: 773804.00
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 735276.00
#   Running DE... ✓ Best: 756894.00
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 733928.00
#   Running DE... ✓ Best: 767014.00
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 745928.00
#   Running DE... ✓ Best: 783186.00
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 732410.00
#   Running DE... ✓ Best: 760840.00
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 758898.00
#   Running DE... ✓ Best: 768504.00
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 745878.00
#   Running DE... ✓ Best: 763864.00
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 761532.00
#   Running DE... ✓ Best: 769886.00
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 757486.00
#   Running DE... ✓ Best: 777922.00
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 722544.00
#   Running DE... ✓ Best: 768600.00
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 737556.00
#   Running DE... ✓ Best: 764520.00
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 738822.00
#   Running DE... ✓ Best: 758126.00
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 738550.00
#   Running DE... ✓ Best: 762252.00
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 730494.00
#   Running DE... ✓ Best: 751002.00
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 719738.00
#   Running DE... ✓ Best: 782172.00
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 747278.00
#   Running DE... ✓ Best: 754792.00
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 725806.00
#   Running DE... ✓ Best: 771500.00
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 747030.00
#   Running DE... ✓ Best: 771928.00
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 747266.00
#   Running DE... ✓ Best: 786792.00
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 735108.00
#   Running DE... ✓ Best: 768824.00
#
# Statistical Summary:
# Algorithm Mean Cost  Std Dev Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA 740638.00 11859.26 716130.00  763154.00        17.897  703482           5.282
#        DE 768870.00  9041.00 751002.00  786792.00        15.835  703482           9.295
#
# T-test: t=-10.195, p=0.0000
#
# tai20a completed:
#   GA - Best: 716130.00,
#   Mean: 740638.00
#   DE - Best: 751002.00,
#   Mean: 768870.00
# Tuning GA hyperparameters for tai25a...
# Tuning DE hyperparameters for tai25a...
#
# Optimal parameters identified for tai25a!
#  > Tuned GA: MutRate=0.054, Elite=4
#  > Tuned DE: Strategy=best/1/bin, F=0.514
#
# ============================================================
# Running 30 experiments for tai25a
# ============================================================
#
# ▶ Run 1/30
#   Running GA... ✓ Best: 1226694.00
#   Running DE... ✓ Best: 1268362.00
#
# ▶ Run 2/30
#   Running GA... ✓ Best: 1228576.00
#   Running DE... ✓ Best: 1267222.00
#
# ▶ Run 3/30
#   Running GA... ✓ Best: 1200618.00
#   Running DE... ✓ Best: 1288720.00
#
# ▶ Run 4/30
#   Running GA... ✓ Best: 1225148.00
#   Running DE... ✓ Best: 1279182.00
#
# ▶ Run 5/30
#   Running GA... ✓ Best: 1208980.00
#   Running DE... ✓ Best: 1278186.00
#
# ▶ Run 6/30
#   Running GA... ✓ Best: 1209426.00
#   Running DE... ✓ Best: 1280278.00
#
# ▶ Run 7/30
#   Running GA... ✓ Best: 1258750.00
#   Running DE... ✓ Best: 1272260.00
#
# ▶ Run 8/30
#   Running GA... ✓ Best: 1220392.00
#   Running DE... ✓ Best: 1267522.00
#
# ▶ Run 9/30
#   Running GA... ✓ Best: 1238738.00
#   Running DE... ✓ Best: 1300976.00
#
# ▶ Run 10/30
#   Running GA... ✓ Best: 1227224.00
#   Running DE... ✓ Best: 1278260.00
#
# ▶ Run 11/30
#   Running GA... ✓ Best: 1222186.00
#   Running DE... ✓ Best: 1266454.00
#
# ▶ Run 12/30
#   Running GA... ✓ Best: 1233428.00
#   Running DE... ✓ Best: 1288454.00
#
# ▶ Run 13/30
#   Running GA... ✓ Best: 1227698.00
#   Running DE... ✓ Best: 1270184.00
#
# ▶ Run 14/30
#   Running GA... ✓ Best: 1248554.00
#   Running DE... ✓ Best: 1314994.00
#
# ▶ Run 15/30
#   Running GA... ✓ Best: 1203454.00
#   Running DE... ✓ Best: 1286286.00
#
# ▶ Run 16/30
#   Running GA... ✓ Best: 1224808.00
#   Running DE... ✓ Best: 1275216.00
#
# ▶ Run 17/30
#   Running GA... ✓ Best: 1212140.00
#   Running DE... ✓ Best: 1294774.00
#
# ▶ Run 18/30
#   Running GA... ✓ Best: 1215630.00
#   Running DE... ✓ Best: 1285256.00
#
# ▶ Run 19/30
#   Running GA... ✓ Best: 1253542.00
#   Running DE... ✓ Best: 1265902.00
#
# ▶ Run 20/30
#   Running GA... ✓ Best: 1239140.00
#   Running DE... ✓ Best: 1283694.00
#
# ▶ Run 21/30
#   Running GA... ✓ Best: 1238974.00
#   Running DE... ✓ Best: 1270116.00
#
# ▶ Run 22/30
#   Running GA... ✓ Best: 1234026.00
#   Running DE... ✓ Best: 1272986.00
#
# ▶ Run 23/30
#   Running GA... ✓ Best: 1229614.00
#   Running DE... ✓ Best: 1275528.00
#
# ▶ Run 24/30
#   Running GA... ✓ Best: 1202680.00
#   Running DE... ✓ Best: 1244732.00
#
# ▶ Run 25/30
#   Running GA... ✓ Best: 1225710.00
#   Running DE... ✓ Best: 1279926.00
#
# ▶ Run 26/30
#   Running GA... ✓ Best: 1226532.00
#   Running DE... ✓ Best: 1261844.00
#
# ▶ Run 27/30
#   Running GA... ✓ Best: 1190914.00
#   Running DE... ✓ Best: 1287806.00
#
# ▶ Run 28/30
#   Running GA... ✓ Best: 1225962.00
#   Running DE... ✓ Best: 1275598.00
#
# ▶ Run 29/30
#   Running GA... ✓ Best: 1231752.00
#   Running DE... ✓ Best: 1258916.00
#
# ▶ Run 30/30
#   Running GA... ✓ Best: 1229432.00
#   Running DE... ✓ Best: 1269174.00
#
# Statistical Summary:
# Algorithm  Mean Cost  Std Dev  Best Cost Worst Cost Mean Time (s) Optimal Optimal Gap (%)
#        GA 1225357.40 15121.31 1190914.00 1258750.00        32.552 1167256           4.978
#        DE 1276960.27 13215.19 1244732.00 1314994.00        35.336 1167256           9.398
#
# T-test: t=-13.838, p=0.0000
#
# tai25a completed:
#   GA - Best: 1190914.00,
#   Mean: 1225357.40
#   DE - Best: 1244732.00,
#   Mean: 1276960.27
# Tuning GA hyperparameters for tai30a...
# [W 2026-08-20 17:35:55,171] Trial 10 failed with parameters: {'population_size': 300, 'max_generations': 400, 'mutation_rate': 0.24268890658908776, 'crossover_rate': 0.7541312313914085, 'elitism_count': 7, 'tournament_size': 3} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/5w/pykqpnlx6hg25lk5bfyrrpd40000gn/T/ipykernel_42759/771200351.py", line 43, in objective
#     _, best_cost = ga.evolve()
#                    ~~~~~~~~~^^
#   File "/var/folders/5w/pykqpnlx6hg25lk5bfyrrpd40000gn/T/ipykernel_42759/3058358786.py", line 194, in evolve
#     fitness_scores = self.calculate_fitness()
#   File "/var/folders/5w/pykqpnlx6hg25lk5bfyrrpd40000gn/T/ipykernel_42759/3058358786.py", line 50, in calculate_fitness
#     return [self.problem.get_fitness(ind) for ind in self.population]
#             ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^
#   File "/var/folders/5w/pykqpnlx6hg25lk5bfyrrpd40000gn/T/ipykernel_42759/3522714163.py", line 125, in get_fitness
#     return 1.0 / (self.evaluate(assignment) + 1e-10)
#                   ~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/var/folders/5w/pykqpnlx6hg25lk5bfyrrpd40000gn/T/ipykernel_42759/3522714163.py", line 119, in evaluate
#     total_cost += self.flow_matrix[i][j] * \
#     ^^^^^^^^^^
# KeyboardInterrupt
# [W 2026-08-20 17:35:55,179] Trial 10 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 8
#       4 # Run all experiments using the self-improving benchmark
#       5 print("Starting CSC528 Project Experiments with Self-Improving Benchmarks...")
#       6 print("This may take several minutes depending on your hardware.")
#       7
# ----> 8 all_results = run_self_improving_benchmarks(tsp_instances, qap_instances)
#       9
#      10 # Generate final summary and visualizations
#      11 summary_df = create_final_summary(all_results)
#
# Cell In[18], line 188, in run_self_improving_benchmarks(tsp_instances, qap_instances)
#     184             print(f"Loading cached GA parameters for {name}...")
#     185             with open(ga_cache_file, 'r') as f:
#     186                 tuned_ga_params = json.load(f)
#     187         else:
# --> 188             tuned_ga_params = tuner.tune_genetic_algorithm(n_trials=25)
#     189             with open(ga_cache_file, 'w') as f:
#     190                 json.dump(tuned_ga_params, f, indent=2)
#     191
#
# Cell In[18], line 54, in SelfImprovingOptimizer.tune_genetic_algorithm(self, n_trials)
#      50             return float(np.mean(costs))
#      51
#      52         pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=1, interval_steps=1)
#      53         study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42), pruner=pruner)
# ---> 54         study.optimize(objective, n_trials=n_trials)
#      55
#      56         # Format discovered parameters cleanly back for the ExperimentRunner structure
#      57         best_params = study.best_params
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/optuna/study/study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# Cell In[18], line 43, in SelfImprovingOptimizer.tune_genetic_algorithm.<locals>.objective(trial)
#      39             # short instead of always paying for all repeats.
#      40             costs = []
#      41             for repeat in range(3):
#      42                 ga = GeneticAlgorithm(self.problem, **params)
# ---> 43                 _, best_cost = ga.evolve()
#      44                 costs.append(best_cost)
#      45
#      46                 trial.report(float(np.mean(costs)), step=repeat)
#
# Cell In[15], line 194, in GeneticAlgorithm.evolve(self)
#     190         """Main execution evolution loop"""
#     191         self.initialize_population()
#     192
#     193         for generation in range(self.max_generations):
# --> 194             fitness_scores = self.calculate_fitness()
#     195
#     196             # Identify current generation champions
#     197             sorted_indices = np.argsort(fitness_scores)[::-1] # Highest fitness first
#
# Cell In[15], line 50, in GeneticAlgorithm.calculate_fitness(self)
#      47     def calculate_fitness(self) -> List[float]:
#      48         """Calculate fitness for entire population"""
#      49         # Ensure your fitness evaluator accurately reflects lower costs as higher values
# ---> 50         return [self.problem.get_fitness(ind) for ind in self.population]
#
# Cell In[13], line 125, in QAPProblem.get_fitness(self, assignment)
#     123     def get_fitness(self, assignment: List[int]) -> float:
#     124         """Convert cost to fitness (for GA)"""
# --> 125         return 1.0 / (self.evaluate(assignment) + 1e-10)
#
# Cell In[13], line 119, in QAPProblem.evaluate(self, assignment)
#     115         """Calculate total assignment cost"""
#     116         total_cost = 0.0
#     117         for i in range(self.n):
#     118             for j in range(self.n):
# --> 119                 total_cost += self.flow_matrix[i][j] * \
#     120                              self.distance_matrix[assignment[i]][assignment[j]]
#     121         return total_cost
#
# KeyboardInterrupt:

# %%
# @title Comprehensive results dictionary for export

import json
import numpy as np # Ensure numpy is imported for np.float64 and np.int64 checks

# Create a comprehensive results dictionary for export
report_data = {
    'summary': summary_df.to_dict('records'),
    'instances': {}
}

for problem_name, result in all_results.items():
    stats_df = result['statistics']
    test = result['test']

    # Iterate through t_test results to convert NumPy types to standard Python types
    for key, value in test.items():
        if isinstance(value, np.bool_):
            test[key] = bool(value)
        elif isinstance(value, np.integer): # Catch np.int64, np.int32, etc.
            test[key] = int(value)
        elif isinstance(value, np.floating): # Catch np.float64, np.float32, etc.
            test[key] = float(value)

    # Convert NumPy arrays in best_solutions to standard Python lists of integers
    ga_best_solution = [int(x) for x in result['runner'].results['GA']['solutions'][
        np.argmin(result['runner'].results['GA']['costs'])
    ]]
    de_best_solution = [int(x) for x in result['runner'].results['DE']['solutions'][
        np.argmin(result['runner'].results['DE']['costs'])
    ]]

    report_data['instances'][problem_name] = {
        'type': result['type'],
        'problem_size': (tsp_instances[problem_name].n_cities if problem_name in tsp_instances
                        else qap_instances[problem_name].n),
        'optimal_solution': (tsp_instances[problem_name].optimal_solution if problem_name in tsp_instances
                           else qap_instances[problem_name].optimal_solution),
        'statistics': stats_df.to_dict('records'),
        't_test': test,
        'best_solutions': {
            'GA': ga_best_solution,
            'DE': de_best_solution
        }
    }

# Save to JSON for report
with open('report_data.json', 'w') as f:
    json.dump(report_data, f, indent=2)

print("Report data saved to 'report_data.json'")
print("\nThis data can be used to create charts and tables for your report.")

# Display best solutions for TSP instances
print("\n" + "=" * 70)
print("BEST SOLUTIONS FOUND")
print("=" * 70)

for problem_name in tsp_instances.keys():
    if problem_name in all_results:
        result = all_results[problem_name]
        runner = result['runner']

        ga_best_idx = np.argmin(runner.results['GA']['costs'])
        de_best_idx = np.argmin(runner.results['DE']['costs'])

        ga_best_cost = runner.results['GA']['costs'][ga_best_idx]
        de_best_cost = runner.results['DE']['costs'][de_best_idx]

        print(f"\n{problem_name} (Optimal: {tsp_instances[problem_name].optimal_solution}):")
        print(f"  GA Best: {ga_best_cost:.2f} "
              f"({(ga_best_cost/tsp_instances[problem_name].optimal_solution - 1)*100:.2f}% gap)")
        print(f"  DE Best: {de_best_cost:.2f} "
              f"({(de_best_cost/tsp_instances[problem_name].optimal_solution - 1)*100:.2f}% gap)")

for problem_name in qap_instances.keys():
    if problem_name in all_results:
        result = all_results[problem_name]
        runner = result['runner']

        ga_best_idx = np.argmin(runner.results['GA']['costs'])
        de_best_idx = np.argmin(runner.results['DE']['costs'])

        ga_best_cost = runner.results['GA']['costs'][ga_best_idx]
        de_best_cost = runner.results['DE']['costs'][de_best_idx]

        print(f"\n{problem_name} (Optimal: {qap_instances[problem_name].optimal_solution}):")
        print(f"  GA Best: {ga_best_cost:.2f} "
              f"({(ga_best_cost/qap_instances[problem_name].optimal_solution - 1)*100:.2f}% gap)")
        print(f"  DE Best: {de_best_cost:.2f} "
              f"({(de_best_cost/qap_instances[problem_name].optimal_solution - 1)*100:.2f}% gap)")
